# %%
import pandas as pd
import numpy as np
import re
import math

# %%
carr=pd.read_csv("Carr_final_sc.csv",encoding = "ISO-8859-1")

# %%
carr2=pd.read_csv("Carr2_final_sc.csv",encoding = "ISO-8859-1")

# %%
mer=pd.read_csv("mercadona_finalsc.csv",encoding = "ISO-8859-1")

# %%
dia=pd.read_csv("Dia_finalsc.csv",encoding = "ISO-8859-1")
dia1=pd.read_csv("Dia1_final_sc.csv",encoding = "ISO-8859-1")
dia2=pd.read_csv("Dia2_final_sc.csv",encoding = "ISO-8859-1")

# %%
 'Ã\x83Â\x91oras Hacendado' borrar producto

# %%
lista= list(mer.producto.unique())
lista
# Out:
# ['Aceite de oliva 0.4Âº Hacendado',
#  'Aceite de oliva virgen extra Hacendado',
#  'Aceite de oliva virgen extra Hacendado Gran Seleccion',
#  'Aceite de oliva 1Âº Hacendado',
#  'Aceite de oliva virgen Hacendado',
#  'Aceite de oliva virgen extra Picual Casa Juncal',
#  'Aceite de girasol refinado 0.2Âº Hacendado',
#  'Aceite de aguacate Ethnos',
#  'Aceite de coco virgen Hacendado',
#  'Vinagre de vino blanco Hacendado',
#  'Vinagre balsamico de Modena Hacendado',
#  'Vinagre de manzana Hacendado',
#  'Limon exprimido Hacendado',
#  'Crema de vinagre balsamico de Modena Hacendado',
#  'Vinagre de Jerez reserva Hacendado',
#  'Bebida aromatizada a base de vino para cocinar Abuela Carola',
#  'Vinagre de vino tinto Hacendado',
#  'Reduccion de vinagre Pedro Ximenez Hacendado',
#  'Aceite de oliva. vinagre y sal Merry',
#  'Crema de vinagre balsamico de manzana Hacendado',
#  'Sal fina Hacendado',
#  'Sal fina de mesa Hacendado',
#  'Sal yodada fina Hacendado',
# ...

# %%
def categorias(a):
    if "agua mineral" in a.lower():
        return "agua mineral"
    if "aceite de oliva virgen extra" in a.lower() and " en " not in a.lower() and " con " not in a.lower():
        return "aceite de oliva virgen extra"
    if "aceite de oliva" in a.lower() and " en " not in a.lower() and " con " not in a.lower():
        return "aceite de oliva"
    if "aceite de girasol" in a.lower() and " en " not in a.lower() and " con " not in a.lower():
        return "aceite de girasol"
    if "aceite de girasol" in a.lower() and " en " not in a.lower() and " con " not in a.lower():
        return "aceite de girasol"
    if "aceite de coco" in a.lower() and " en " not in a.lower() and " con " not in a.lower():
        return "aceite de coco"
    if "aceite de aguacate" in a.lower() and " en " not in a.lower() and " con " not in a.lower():
        return "aceite de aguacate"
    if "vinagre" in a.lower() and "blanco" in a.lower() and " con " not in a.lower():
        return "vinagre de vino blanco"
    if "vinagre" in a.lower() and "tinto" in a.lower()and " con " not in a.lower():
        return "vinagre"
    if "vinagre" in a.lower() and "balsamico" in a.lower() and " con " not in a.lower():
        return "vinagre balsamico"
    if "vinagre" in a.lower() and "jerez" in a.lower() and " con " not in a.lower():
        return "vinagre de jerez"
    if "vinagre" in a.lower() and "reduccion" in a.lower():
        return "reduccion de vinagre"
    if "vinagre" in a.lower() and "crema" in a.lower() and " con " not in a.lower():
        return "reduccion de vinagre"
    if "sal " in a.lower() and "fina" in a.lower():
        return "sal fina"
    if "sal " in a.lower() and "gruesa" in a.lower() and "horn" not in a.lower():
        return "sal gruesa"
    if "sal " in a.lower() and "hornear" in a.lower():
        return "sal para hornear"
    if "sal rosa" in a.lower() and "himalaya" in a.lower():
        return "sal rosa del himalaya"
    if "sal " in a.lower() and "de frutas" not in a.lower() and "fina" not in a.lower() and "gruesa" not in a.lower() and "rosa" not in a.lower():
        return "sal"
    if "bicarbonato sodico" in a.lower():
        return "bicarbonato sodico"
    if "sal de frutas" in a.lower():
        return "sal de frutas"
    if "oregano" in a.lower() and " con " not in a.lower():
        return "oregano"
    if "perejil" in a.lower() and " con " not in a.lower():
        return "perejil"
    if "laurel" in a.lower() and " con " not in a.lower():
        return "laurel"
    if "hierbas provenzales" in a.lower() and " con " not in a.lower():
        return "hierbas provenzales"
    if "romero"in a.lower() and " con " not in a.lower():
        return "romero"
    if "albahaca" in a.lower() and " con " not in a.lower():
        return "albahaca"
    if "tomillo" in a.lower() and " con " not in a.lower():
        return "tomillo"
    if "eneldo" in a.lower() and " con " not in a.lower():
        return "eneldo"
    if "cilantro" in a.lower() and " con " not in a.lower():
        return "cilantro"
    if "colorante alimentario" in a.lower() and " con " not in a.lower():
        return "colorante alimentario"
    if "pimenton" in a.lower() and "dulce" in a.lower() and " con " not in a.lower():
        return "pimenton dulce"
    if "pimenton" in a.lower() and "picante" in a.lower() and " con " not in a.lower():
        return "pimenton picante"
    if "azafran" in a.lower() and " con " not in a.lower():
        return "azafran"
    if "pimienta" in a.lower() and "negra" in a.lower() and " con " not in a.lower():
        return "pimienta negra"
    if "pimienta" in a.lower() and "blanca" in a.lower() and " con " not in a.lower():
        return "pimienta blanca"
    if "pimienta" in a.lower() and "verde" in a.lower() and " con " not in a.lower():
        return "pimienta verde"
    if "ajo" in a.lower() and "granulado" in a.lower():
        return "ajo en polvo"
    if "ajo" in a.lower() and "polvo" in a.lower():
        return "ajo en polvo"
    if "pinones" in a.lower()and " con " not in a.lower():
        return "pinones"
    if "cebolla" in a.lower() and "crujiente" in a.lower()and " con " not in a.lower():
        return "cebolla frita crujiente"
    if "canela" in a.lower() and " con " not in a.lower(): 
        return "canela"
    if "comino" in a.lower() and " con " not in a.lower(): 
        return "comino"
    if "curry" in a.lower() and " con " not in a.lower() and " al " not in a.lower():
        return "curry"
    if "nuez moscada" in a.lower() and " con " not in a.lower():
        return "nuez moscada"
    if "curcuma" in a.lower() and " con " not in a.lower():
        return "curcuma"
    if "jengibre" in a.lower() and " con " not in a.lower() and " y " not in a.lower() and "zumo" not in a.lower():
        return "jengibre"
    if "clavo" in a.lower() and "grano" in a.lower():
        return "clavo en grano"
    if "vainilla" in a.lower() and " de " not in a.lower() and "sabor" not in a.lower() and "aroma" not in a.lower():
        return "vainilla"
    if "trufas" in a.lower():
        return "trufas"
    if "anis" in a.lower() and " de " not in a.lower() and "sabor" not in a.lower() and "licor" not in a.lower():
        return "anis"
    if "pimientos choriceros" in a.lower():
        return "pimientos choriceros"
    if "sazonador" in a.lower():
        return "sazonador"
    if "mayonesa" in a.lower():
        return "mayonesa"
    if "ketchup" in a.lower():
        return "ketchup"
    if "mostaza" in a.lower() and " con " not in a.lower():
        return "mostaza"
    if "allioli" in a.lower() and " con " not in a.lower():
        return "allioli"
    if "alioli" in a.lower() and " con " not in a.lower():
        return "allioli"
    if "alli oli" in a.lower() and " con " not in a.lower():
        return "allioli"
    if "tomate frito" in a.lower() and " con " not in a.lower():
        return "tomate frito"
    if "salsa" in a.lower() and "barbacoa" in a.lower() and " con " not in a.lower():
        return "salsa barbacoa"
    if "salsa" in a.lower() and "bbq" in a.lower() and " con " not in a.lower():
        return "salsa barbacoa"
    if "salsa" in a.lower() and "bolonesa" in a.lower() and " con " not in a.lower():
        return "salsa bolonesa"
    if "salsa" in a.lower() and "pesto" in a.lower() and " con " not in a.lower():
        return "salsa pesto"
    if "salsa" in a.lower() and "piri piri" in a.lower() and " con " not in a.lower():
        return "salsa piri piri"
    if "salsa" in a.lower() and "chimichurri" in a.lower() and " con " not in a.lower():
        return "salsa chimichurri"
    if "salsa" in a.lower() and "roquefort" in a.lower() and " con " not in a.lower():
        return "salsa roquefort"
    if "salsa" in a.lower() and "carbonara" in a.lower() and " con " not in a.lower():
        return "salsa carbonara"
    if "salsa" in a.lower() and "ranchera" in a.lower() and " con " not in a.lower():
        return "salsa ranchera" 
    if "salsa" in a.lower() and "setas" in a.lower() and " con " not in a.lower():
        return "salsa setas"
    if "salsa" in a.lower() and "teriyaki" in a.lower() and " con " not in a.lower():
        return "salsa teriyaki"
    if "salsa" in a.lower() and "soja" in a.lower() and " con " not in a.lower():
        return "salsa soja"
    if "salsa" in a.lower() and "agridulce" in a.lower() and " con " not in a.lower():
        return "agridulce"
    if "salsa" in a.lower() and "brava" in a.lower() and " con " not in a.lower():
        return "salsa brava"
    if "salsa" in a.lower() and "mexicana" in a.lower() and " con " not in a.lower():
        return "salsa mexicana"
    if "salsa" in a.lower() and "cesar" in a.lower() and " con " not in a.lower():
        return "salsa cesar"
    if "salsa" in a.lower() and "caesar" in a.lower() and " con " not in a.lower():
        return "salsa cesar"
    if "salsa" in a.lower() and " con " not in a.lower() and "barbacoa" not in a.lower() and "bbq" not in a.lower() and "bolonesa" not in a.lower() and "pesto" not in a.lower() and "piri piri" not in a.lower() and "chimichurri" not in a.lower() and "roquefort" not in a.lower() and "carbonara" not in a.lower() and "ranchera" not in a.lower() and "setas" not in a.lower() and"teriyaki" not in a.lower() and "soja" not in a.lower() and "agridulce" not in a.lower() and "brava" not in a.lower() and "mexicana" not in a.lower() and "cesar" not in a.lower() and "caesar" not in a.lower() and "tabasco" not in a.lower() and "queso" not in a.lower():
        return "salsa"
    if "tabasco" in a.lower() and " con " not in a.lower():
        return "tabasco"
    if "bechamel" in a.lower() and " con " not in a.lower():
        return "bechamel"
    if "guacamole" in a.lower():
        return "guacamole"
    if "alino" in a.lower():
        return "alino"
    if "salsa" in a.lower() and "queso" in a.lower() and " con " not in a.lower():
        return "salsa de queso"
    if "mojo" in a.lower() and "canar" in a.lower() and " con " not in a.lower():
        return "mojo canario"
    if "agua" in a.lower() and "micelar" not in a.lower() and "mineral" not in a.lower():
        return "agua otro"
    if "gaseosa" in a.lower():
        return "gaseosa"
    if "isotonica" in a.lower():
        return "bebida isotonica"
    if "bebida energetica" in a.lower():
        return "bebida energetica"
    if "red bull" in a.lower():
        return "bebida energetica"
    if "redbull" in a.lower():
        return "bebida energetica"
    if "monster" in a.lower():
        return "bebida energetica"
    if "gel" in a.lower() and " en " not in a.lower() and "sabor" not in a.lower():
        return "gel de ducha"
    if " cola " in a.lower() and "caballo" not in a.lower():
        return "cocacola"
    if "coca-cola" in a.lower():
        return "cocacola"
    if "limon" in a.lower() and "fanta" in a.lower():
        return "refresco limon"
    if "limon" in a.lower() and "schweppes" in a.lower():
        return "refresco limon"
    if "limon" in a.lower() and "refresco" in a.lower():
        return "refresco limon"
    if "naranja" in a.lower() and "fanta" in a.lower():
        return "refresco naranja"
    if "naranja" in a.lower() and "schweppes" in a.lower():
        return "refresco naranja"
    if "naranja" in a.lower() and "refresco" in a.lower():
        return "refresco naranja"
    if "sprite" in a.lower():
        return "sprite"
    if "7 up" in a.lower():
        return "7 up"
    if "acuarius" in a.lower():
        return "acuarius"
    if "tonica" in a.lower():
        return "tonica"
    if "nestea" in a.lower():
        return "nestea"
    if "refresco" in a.lower() and " te " in a.lower():
        return "nestea"
    if "refresco" in a.lower() and "naranja" not in a.lower() and "cola" not in a.lower() and "tonica" not in a.lower() and "sprite" not in a.lower() and "nestea" not in a.lower() and "te" not in a.lower() and "limon" not in a.lower() and "acuarius" not in a.lower() and "energetic" not in a.lower() and "red bull" not in a.lower() and "redbull" not in a.lower() and "monster" not in a.lower():
        return "refresco otro"
    if "aceitunas" in a.lower() and "negras" not in a.lower():
        return "aceitunas"
    if "aceitunas" in a.lower() and "negras" in a.lower():
        return "aceitunas negras"
    if "banderillas" in a.lower():
        return "banderillas"
    if "penillos" in a.lower():
        return "penillos"
    if "altramuces" in a.lower():
        return "altramuces"
    if "alcaparr" in a.lower():
        return "alcaparras"
    if "cebollitas" in a.lower():
        return "cebollitas en vinagre"
    if "guindilla" in a.lower() and "vinagre" in a.lower() or "encurtid" in a.lower():
        return "guidillas en vinagre"
    if "piparra" in a.lower():
        return "piparras en vinagre"
    if "encurtid" in a.lower() and "banderillas" not in a.lower() and "pepinillos" not in a.lower() and "altramuces" not in a.lower() and "alcaparras" not in a.lower() and "cebollitas" not in a.lower() and "guindillas" not in a.lower()  and "piparras" not in a.lower():
        return "encurtidos otro"
    if "nuez" in a.lower() and "moscada" not in a.lower() and " con " in a.lower() and " de " in a.lower():
        return "nueces"
    if "nueces" in a.lower() and " con " in a.lower() and " de " in a.lower():
        return "nueces"
    if "pistacho" in a.lower() and "mix" not in a.lower() and "coctel" not in a.lower() and "cocktail" not in a.lower():
        return "pistachos"
    if "pipas" in a.lower() and "mix" not in a.lower() and "coctel" not in a.lower() and "cocktail" not in a.lower():
        return "pipas"
    if "anacardo" in a.lower() and "mix" not in a.lower() and "coctel" not in a.lower() and "cocktail" not in a.lower():
        return "anacardos"
    if "avellana" in a.lower() and "mix" not in a.lower() and "coctel" not in a.lower() and "cocktail" not in a.lower():
        return "avellanas"
    if "almendra" in a.lower() and "mix" not in a.lower() and "coctel" not in a.lower() and "cocktail" not in a.lower():
        return "almendras"
    if "maiz" in a.lower() and "frito" in a.lower() and "mix" not in a.lower() and "coctel" not in a.lower() and "cocktail" not in a.lower():
        return "maiz frito (quicos)"
    if "palomitas" in a.lower() and "mix" not in a.lower() and "coctel" not in a.lower() and "cocktail" not in a.lower():
        return "palomitas"
    if "semillas" in a.lower() and " con " not in a.lower():
        return "semillas"
    if "castanas" in a.lower():
        return "castanas"
    if "peladillas" in a.lower():
        return "peladillas"
    if "frutos secos" in a.lower() and " con " not in a.lower():
        return "frutos secos"
    if "cocktail" in a.lower():
        return "mix aperitivo"
    if "pasas" in a.lower() and " con " not in a.lower():
        return "pasas"
    if "patatas fritas" in a.lower() and "congelad" not in a.lower():
        return "patatas fritas apetiritivo"
    
    else:
        return "nada"

# %%
 'Pasas sultanas sin semillas Hacendado',
 'Mango deshidratado Hacendado',
 'Manzana roja deshidratada Hacendado',
 'Ciruelas desecadas sin hueso Hacendado',
 'Datiles sin hueso Hacendado',
 'Arandanos deshidratados Hacendado',
 'Pina deshidratada Hacendado',
 'Orejones albaricoque Hacendado',
 'Datiles en rama Casa Pons',
 'Pasas moscatel sin semillas Hacendado',
 'Higo seco Villacruz',
 'Higos tiernos deshidratados Noberasco',
 'Pan de higo con almendras De Juan',
 'Pan de datil con nueces De Juan',
 'Fruta surtida confitada Frutas 1943',
 'Calabaza glaseada Frutas 1943',
 'Datiles Medjoul con hueso Hacendado',
 'Patatas fritas estilo tradicional Hacendado',
 'Patatas fritas extra crujientes Hacendado',
 'Patatas fritas corte ondulado Hacendado',
 'Patatas fritas receta churreria Hacendado',
 'Patatas fritas onduladas Hacendado sabor jamon serrano',
 'Patatas fritas crujientes a la sarten Hacendado',
 "Patatas fritas al punto de sal Lay's",
 'Patatas fritas sabor limon y pimienta Hacendado',
 'Patatas fritas onduladas Ruffles sabor jamon',
 'Patatinas extra crujientes Hacendado',
 'Patatas light Hacendado',
 'Patatas fritas sabor huevo frito Hacendado',
 "Patatas fritas receta campesina Lay's",
 'Pringles original',
 'Varitas sabor ketchup Hacendado',
 'Pringles sabor crema agria y cebolla',
 'Patatas fritas 0% sal anadida Hacendado',
 'Patatas fritas onduladas Munchos sabor queso',
 'Trigo snack sabor ahumado Hacendado',
 'Patatas fritas sabor chili y lima Hacendado',
 'Patatas fritas paja Hacendado',
 'Patatas fritas sabor pollo y limon Hacendado',
 'Patatas fritas sabor sal y vinagre Hacendado',
 'Nachos Hacendado',
 'Conos sabor bacon y queso Hacendado',
 'Triangulos de maiz Tex-Mex Doritos',
 'Pandilla sabor queso Cheetos',
 'Tiras de maiz frito sabor barbacoa Hacendado',
 'Nachos tex-mex Hacendado sabor queso',
 'Galletitas saladas Hacendado',
 'Combinado de aperitivos Hacendado',
 'Cuquitos sabor queso Hacendado',
 'Cuquis Hacendado',
 'Garfitos de maiz sabor queso Hacendado',
 'Tortitas de maiz con legumbres Hacendado',
 'Snack de gamba Hacendado',
 'Bombitas de maiz sabor mantequilla Hacendado',
 'Torreznos Hacendado',
 'Torreznos sabor barbacoa Hacendado',
 "Snacks de lenteja sabor queso y especias Snatt's",
 'Bolitas sabor barbacoa Hacendado',
 'Varitas de patata Hacendado',
 'Cocktail galletitas de aperitivo Hacendado',
 'Cortezas',
 'Palomitas caramelo Hacendado',
 'Snack de alga con arroz Hacendado',
 'Super cuquis La Llanura',
 'Pelotazos sabor queso Cheetos',
 'Nachos Padrisimos Hacendado sabor guacamole',
 'Aros de maiz Hacendado',
 'Snack de maiz sabor barbacoa Estrella',
 'Snack multicereal Hacendado',
 'Jumpers de maiz sabor mantequilla',
 'Triangulos de patata Estrella sabor jamon',
 'Surtido de snacks Picoteo de maiz y patata Tosfrit',
 'Arroz redondo Hacendado',
 'Arroz cocido basmati Sabroz',
 'Arroz cocido integral Sabroz',
 'Arroz bomba Hacendado',
 'Arroz cocido redondo Sabroz',
 'Quinoa cocida blanca y roja Sabroz',
 'Arroz largo Hacendado',
 'Arroz redondo J Sendra Hacendado',
 'Arroz basmati aromatico Hacendado',
 'Cous cous mediano Bia',
 'Arroz integral redondo Hacendado',
 'Quinoa Hacendado',
 'Arroz vaporizado Hacendado',
 'Arroz redondo Sabroz',
 'Arroz Jazmin aromatico Hacendado',
 'Arroz arborio especial risotto Hacendado',
 'Arroz especial ensaladas y guarnicion Hacendado',
 'Arroz redondo SOS',
 'Arroz vaporizado Brillante',
 'Arroz integral largo Hacendado',
 'Garbanzo cocido Hacendado',
 'Garbanzo cocido pedrosillano Hacendado',
 'Garbanzo Hacendado',
 'Garbanzo cocido con espinacas Hacendado',
 'Garbanzo pedrosillano Hacendado',
 'Garbanzo lechoso andaluz Hacendado',
 'Alubia cocida blanca Hacendado',
 'Alubia cocida roja Hacendado',
 'Alubia cocida pinta Hacendado',
 'Alubia blanca Hacendado',
 'Alubia cocida con verduras Hacendado',
 'Alubia negra Hacendado',
 'Alubia roja Hacendado',
 'Alubia cocida granja Hacendado',
 'Alubia pinta Hacendado',
 'Alubia granja Hacendado',
 'Lenteja cocida Hacendado',
 'Lenteja pardina Hacendado',
 'Lenteja cocida pardina Hacendado',
 'Lenteja rapida Hacendado',
 'Soja texturizada grano fino Hacendado',
 'Lenteja Hacendado',
 'Lenteja pelada Hacendado',
 'Fideo cabello de angel Hacendado',
 'Fideua Hacendado',
 'Fideo grueso Hacendado',
 'Pasta estrellas Hacendado',
 'Pasta maravilla Hacendado',
 'Fideo mediano Hacendado',
 'Fideo al huevo Hacendado',
 'Pasta infantil con vegetales Hacendado',
 'Fideo integral Hacendado',
 'Semola de trigo fina Nurture',
 'Tapioca Tipiak',
 'Fideo sin gluten con quinoa Felicia',
 'Pajaritas vegetales Hacendado',
 'Penne integral Hacendado',
 'Tortiglioni Armando',
 'Helices con vegetales Hacendado',
 'Macarron fino Hacendado',
 'Macarron al huevo Hacendado',
 'Macarron Hacendado',
 'Macarron rayado Hacendado',
 'Penne Armando',
 'Fusilli 100% lentejas rojas Felicia',
 'Trottole vegetales Hacendado',
 'Fusilli Armando',
 'Pasta tiburon Hacendado',
 'Penne sin gluten Felicia',
 'Penne de trigo sarraceno Felicia',
 'Helices Hacendado',
 'Fusilli sin gluten vegetales Felicia',
 'Tallarin Hacendado',
 'Spaghetti integral Hacendado',
 'Spaghetti fino Hacendado',
 'Nidos al huevo tagliatelle Hacendado',
 'Spaghetti al huevo Hacendado',
 'Nidos vegetales Hacendado',
 'Spaghetti Hacendado',
 'Spaghetti Armando',
 'Tagliatelle frescos al huevo Hacendado',
 'Spaghetti sin gluten con quinoa Felicia',
 'Tortellini con carne Pagani',
 'Tortelloni fresco carne Hacendado',
 'Ravioli fresco requeson y espinacas Hacendado',
 'Tortellini con tres quesos Pagani',
 'Gnocchi frescos Hacendado',
 'Medialunas frescas setas con boletus Bel Canto',
 'Girasoles frescos con quesos Hacendado',
 'Tortellini con ricotta y espinacas Pagani',
 'Medialunas frescas parmigiano reggiano y trufa Bel Canto',
 'Redondos frescos berenjena. tomate y mozzarella Bel Canto',
 'Medialunas frescas calabaza y crema de quesos Bel Canto',
 'Tortelloni fresco albahaca Hacendado',
 'Gnocchi frescos al pesto Hacendado',
 'Tortellini fresco jamon Hacendado',
 'Tortelloni fresco sin gluten carne Hacendado',
 'Placas para lasana precocidas El Pavo',
 'Placas para canelones tradicionales Hacendado',
 'Cannelloni tubos precocidos Hacendado',
 'Lasana sin gluten de maiz y arroz Felicia',
 'Pasta oriental sabor pollo frango Maggi',
 'Fideos orientales Yakisoba classic Gallina Blanca',
 'Fideos orientales Yatekomo de pollo Gallina Blanca',
 'Fideos orientales Yakisoba de pollo Gallina Blanca',
 'Fideos orientales Yakisoba curry Hacendado',
 'Fideos orientales Yakisoba sabor pollo Hacendado',
 'Pasta oriental sabor gamba camarao Maggi',
 'Fideos orientales Yakisoba soja Hacendado',
 'Fideos orientales Yatekomo Gallina Blanca',
 'Noodles sabor pollo Hacendado',
 'Noodles sabor gamba Hacendado',
 'Noodles sabor picante Hacendado',
 'Ramen con panceta Hacendado',
 'Azucar blanco',
 'Azucar blanco en sobres Acor',
 'Azucar moreno de cana Acor',
 'Azucar moreno de cana integral en sobres Acor',
 'Panela azucar moreno de cana integral Hacendado',
 'Azucar glas Hacendado',
 'Azucar Mascavado Hacendado',
 'Edulcorante liquido sacarina Hacendado',
 'Edulcorante en pastillas sacarina Hacendado',
 'Edulcorante en sobres sacarina Hacendado',
 'Sirope de agave',
 'Edulcorante liquido stevia Hacendado',
 'Edulcorante granulado stevia Hacendado',
 'Edulcorante en pastillas stevia Hacendado',
 'Edulcorante en sobres stevia Hacendado',
 'Edulcorante en pastillas aspartamo Hacendado',
 'Fructosa Hacendado',
 'Edulcorante sucralosa Hacendado',
 'Chicle menta fresca gragea Hacendado',
 'Chicle menta fuerte gragea Hacendado',
 'Chicle hierbabuena gragea Hacendado',
 'Chicle hierbabuena lamina Hacendado',
 'Chicle menta suave gragea Hacendado',
 'Chicle fresa gragea Hacendado',
 'Chicle fresa lamina Hacendado',
 'Chicle original sabor frutas gragea Hacendado',
 'Chicle regaliz y menta gragea Hacendado',
 'Chicle sandia lamina Hacendado',
 'Chicle XXL gragea Hacendado',
 'Chicle jengibre gragea Hacendado',
 'Chicle mentol mix XXL gragea Hacendado',
 'Chicles surtidos gragea Hacendado',
 'Caramelos nata Dolis 0% azucares',
 'Caramelos cafe Dolis 0% azucares',
 'Caramelos sabor eucalipto y mentol Hacendado 0% azucares',
 'Caramelos surtidos 6 sabores Hacendado',
 'Caramelos eucaliptus mentol Respiral Halls',
 'Caramelos citricos mix Halls',
 'Caramelos limon mentol Respiral Halls',
 'Caramelos original Halls',
 'Caramelos blandos Hacendado',
 'Caramelos blandos rellenos Dolis',
 'Caramelos sabor regaliz y mentol Hacendado 0% azucares',
 'Caramelos con palo 4 sabores Chupa Chups',
 'Caramelos menta minigrageas Smint',
 "Caramelos mantequilla y nata Werther's original",
 'Caramelos regaliz mentol Respiral Halls',
 'Caramelos jengibre y propolis Hacendado 0% azucares',
 'Caramelos Mix Fruits Hacendado 0% azucares',
 'Chocolate extrafino negro Hacendado',
 'Chocolate negro Hacendado fundir',
 'Chocolatinas chocolate extrafino negro Hacendado',
 'Chocolate negro Valor 70% chocolate negro',
 'Chocolate extrafino negro Hacendado con pepitas de cacao tostadas',
 'Chocolate negro Hacendado almendras enteras',
 'Chocolate negro Valor puro',
 'Chocolate negro Valor puro almendras enteras',
 'Chocolate extrafino negro Hacendado 0% azucares anadidos',
 'Mini barritas chocolate negro Hacendado con crujiente de semillas y galleta',
 'Chocolate negro Hacendado mousse',
 'Chocolate negro 55% Hacendado con avellanas enteras',
 'Chocolatinas Royal Mints chocolate negro',
 'Chocolate extrafino negro Hacendado fussion relleno sabor menta',
 'Gotas de chocolate negro para fundir Hacendado',
 'Chocolate extrafino negro Hacendado almendras enteras',
 'Chocolate extrafino negro Hacendado con arandanos y sesamo',
 'Chocolate negro Hacendado fundir 0% azucares anadidos',
 '99% cacao extrafino negro Hacendado',
 'Chocolate con leche Hacendado classic',
 'Chocolate con leche Nestle',
 'Chocolate con leche Milka Oreo',
 'Chocolate con leche Lindt',
 'Chocolate con leche Milka',
 'Chocolate extrafino con leche Hacendado almendras enteras',
 'Chocolate con leche Hacendado',
 'Chocolate con leche Valor almendras enteras',
 'Chocolate con leche Hacendado avellanas troceadas',
 'Chocolate extrafino con leche Hacendado 0% azucares anadidos',
 'Chocolate con leche Milka caramelo',
 'Chocolate con leche Hacendado porciones',
 'Chocolate con leche Milka galleta',
 'Chocolate con leche Hacendado almendras troceadas',
 'Chocolate con leche Hacendado almendra troceada y miel',
 'Chocolate con leche Hacendado fussion relleno sabor fresa',
 'Chocolate con leche Hacendado bajo en lactosa',
 'Fideos de chocolate Hacendado',
 'Chocolate con leche Hacendado fundir',
 'Chocolate con leche Bites Cadbury con relleno sabor vainilla y trozos de galleta',
 'Chocolate con leche Crunchie Rocks Cadbury con copos de maiz y trozos de caramelo',
 'Chocolate con leche Hacendado cremoso',
 'Chocolate con leche avellanas Hacendado',
 'Chocolate con leche Fussion Hacendado relleno cremoso. avellanas y barquillo crujiente',
 'Chocolates surtidos y caramelos Heroes Cadbury rellenos de chocolate con leche',
 'Chocolate blanco Hacendado',
 'Chocolate blanco Hacendado fundir',
 'Chocolate blanco Hacendado fussion galletas al cacao',
 'Chocolate blanco Hacendado fussion relleno con cremoso de coco y almendras troceadas',
 'Barritas de barquillo Huesitos banadas de chocolate con leche',
 'Barritas de chocolate con leche Hacendado rellenas de leche',
 'Barritas de barquillo Kit-Kat banadas de chocolate con leche',
 'Barritas de barquillo Tokke original',
 'Barritas de barquillo Kinder Bueno banadas de chocolate con leche',
 'Disquitos Pintarolas de chocolate con leche coloreados',
 'Cacahuetes Hacendado chocolate negro',
 'Cacahuetes Hacendado chocolate con leche',
 'Barritas de chocolate con leche Kinder rellenas de leche',
 'Barritas de galleta y caramelo Hacendado banadas de chocolate con leche',
 'Vasito con crema de cacao Choco Snack Hacendado con palitos de pan',
 'Cacahuetes Chocoiris Hacendado banados de chocolate con leche coloreados',
 'Huevos de chocolate Hacendado dibujo',
 'Almendras Hacendado chocolate negro',
 'Monedas de chocolate con leche',
 'Mini huevos de chocolate con leche Schoko-Bons Kinder rellenos de leche y avellanas',
 'Bolas de cereal Hacendado banadas de chocolate negro. con leche y blanco',

# %%
mer_p=mer

# %%
mer_p["categoria"]=mer_p.producto.apply(categorias)

# %%
mer_p.categoria.unique()
# Out:
# array(['aceite de oliva', 'aceite de oliva virgen extra',
#        'aceite de girasol', 'aceite de aguacate', 'aceite de coco',
#        'vinagre de vino blanco', 'vinagre balsamico', 'nada',
#        'vinagre de jerez', 'vinagre', 'reduccion de vinagre', 'sal fina',
#        'sal gruesa', 'bicarbonato sodico', 'sal', 'sal para hornear',
#        'sal de frutas', 'sal rosa del himalaya', 'oregano', 'perejil',
#        'laurel', 'hierbas provenzales', 'albahaca', 'romero', 'tomillo',
#        'eneldo', 'cilantro', 'colorante alimentario', 'pimenton dulce',
#        'azafran', 'pimenton picante', 'pimienta negra', 'pimienta blanca',
#        'pimienta verde', 'ajo en polvo', 'pinones',
#        'cebolla frita crujiente', 'canela', 'comino', 'curry',
#        'nuez moscada', 'curcuma', 'jengibre', 'clavo en grano',
#        'vainilla', 'trufas', 'anis', 'pimientos choriceros', 'sazonador',
#        'mayonesa', 'salsa', 'ketchup', 'mostaza', 'allioli',
# ...

# %%
filtrado_ud = mer_p.loc[(mer_p["categoria"]!= "nada")]
filtrado_ud
# Out:
#       Unnamed: 0                                           producto  precio  \
# 0              0                    Aceite de oliva 0.4Âº Hacendado   15.50
# 1              1                    Aceite de oliva 0.4Âº Hacendado    3.20
# 2              2             Aceite de oliva virgen extra Hacendado   11.00
# 3              3             Aceite de oliva virgen extra Hacendado    3.95
# 4              4  Aceite de oliva virgen extra Hacendado Gran Se...    4.10
# ...          ...                                                ...     ...
# 6615        6615                        Albondigas en salsa La Nora    1.04
# 6633        6633                    Caracoles en salsa mediterranea    3.95
# 6678        6678  Bifidus de pera. datil y canela Hacendado zero...    1.50
# 6698        6698  Bifidus natural Hacendado con coco. almendras ...    1.05
# 6729        6729                         Copa de avellana Hacendado    1.00
#
#       cantidad medida                     categoria
# ...
