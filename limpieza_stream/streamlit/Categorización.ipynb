# %%
import pandas as pd
import numpy as np
import re
import math

# %%
carr=pd.read_csv("Carr_final_sc.csv",encoding = "ISO-8859-1")

# %%
carr2=pd.read_csv("Carr2_final_sc.csv",encoding = "ISO-8859-1")

# %%
mer=pd.read_csv("mercadona_finalsc.csv",encoding = "ISO-8859-1")

# %%
dia=pd.read_csv("Dia_finalsc.csv",encoding = "ISO-8859-1")
dia1=pd.read_csv("Dia1_final_sc.csv",encoding = "ISO-8859-1")
dia2=pd.read_csv("Dia2_final_sc.csv",encoding = "ISO-8859-1")

# %%
 'Ã\x83Â\x91oras Hacendado' borrar producto
# Out:
#   File "<ipython-input-15-da492335d301>", line 1
#     'Ã\x83Â\x91oras Hacendado' borrar producto
#                                ^
# SyntaxError: invalid syntax

# %%
lista= list(mer.producto.unique())
print(lista)
# Out:
# ['Aceite de oliva 0.4Âº Hacendado', 'Aceite de oliva virgen extra Hacendado', 'Aceite de oliva virgen extra Hacendado Gran Seleccion', 'Aceite de oliva 1Âº Hacendado', 'Aceite de oliva virgen Hacendado', 'Aceite de oliva virgen extra Picual Casa Juncal', 'Aceite de girasol refinado 0.2Âº Hacendado', 'Aceite de aguacate Ethnos', 'Aceite de coco virgen Hacendado', 'Vinagre de vino blanco Hacendado', 'Vinagre balsamico de Modena Hacendado', 'Vinagre de manzana Hacendado', 'Limon exprimido Hacendado', 'Crema de vinagre balsamico de Modena Hacendado', 'Vinagre de Jerez reserva Hacendado', 'Bebida aromatizada a base de vino para cocinar Abuela Carola', 'Vinagre de vino tinto Hacendado', 'Reduccion de vinagre Pedro Ximenez Hacendado', 'Aceite de oliva. vinagre y sal Merry', 'Crema de vinagre balsamico de manzana Hacendado', 'Sal fina Hacendado', 'Sal fina de mesa Hacendado', 'Sal yodada fina Hacendado', 'Sal gruesa Hacendado', 'Bicarbonato sodico Hacendado', 'Sal marina en escamas Polasal',
# ...

# %%
def categorias(a):
    if "agua mineral" in a.lower():
        return "agua mineral"
    if "aceite de oliva virgen extra" in a.lower() and " en " not in a.lower() and " con " not in a.lower():
        return "aceite de oliva virgen extra"
    if "aceite de oliva" in a.lower() and " en " not in a.lower() and " con " not in a.lower():
        return "aceite de oliva"
    if "aceite de girasol" in a.lower() and " en " not in a.lower() and " con " not in a.lower():
        return "aceite de girasol"
    if "aceite de girasol" in a.lower() and " en " not in a.lower() and " con " not in a.lower():
        return "aceite de girasol"
    if "aceite de coco" in a.lower() and " en " not in a.lower() and " con " not in a.lower():
        return "aceite de coco"
    if "aceite de aguacate" in a.lower() and " en " not in a.lower() and " con " not in a.lower():
        return "aceite de aguacate"
    if "vinagre" in a.lower() and "blanco" in a.lower() and " con " not in a.lower():
        return "vinagre de vino blanco"
    if "vinagre" in a.lower() and "tinto" in a.lower()and " con " not in a.lower():
        return "vinagre"
    if "vinagre" in a.lower() and "balsamico" in a.lower() and " con " not in a.lower():
        return "vinagre balsamico"
    if "vinagre" in a.lower() and "jerez" in a.lower() and " con " not in a.lower():
        return "vinagre de jerez"
    if "vinagre" in a.lower() and "reduccion" in a.lower():
        return "reduccion de vinagre"
    if "vinagre" in a.lower() and "crema" in a.lower() and " con " not in a.lower():
        return "reduccion de vinagre"
    if "sal " in a.lower() and "fina" in a.lower():
        return "sal fina"
    if "sal " in a.lower() and "gruesa" in a.lower() and "horn" not in a.lower():
        return "sal gruesa"
    if "sal " in a.lower() and "hornear" in a.lower():
        return "sal para hornear"
    if "sal rosa" in a.lower() and "himalaya" in a.lower():
        return "sal rosa del himalaya"
    if "sal " in a.lower() and "de frutas" not in a.lower() and "fina" not in a.lower() and "gruesa" not in a.lower() and "rosa" not in a.lower():
        return "sal"
    if "bicarbonato sodico" in a.lower():
        return "bicarbonato sodico"
    if "sal de frutas" in a.lower():
        return "sal de frutas"
    if "oregano" in a.lower() and " con " not in a.lower():
        return "oregano"
    if "perejil" in a.lower() and " con " not in a.lower():
        return "perejil"
    if "laurel" in a.lower() and " con " not in a.lower():
        return "laurel"
    if "hierbas provenzales" in a.lower() and " con " not in a.lower():
        return "hierbas provenzales"
    if "romero"in a.lower() and " con " not in a.lower():
        return "romero"
    if "albahaca" in a.lower() and " con " not in a.lower():
        return "albahaca"
    if "tomillo" in a.lower() and " con " not in a.lower():
        return "tomillo"
    if "eneldo" in a.lower() and " con " not in a.lower():
        return "eneldo"
    if "cilantro" in a.lower() and " con " not in a.lower():
        return "cilantro"
    if "colorante alimentario" in a.lower() and " con " not in a.lower():
        return "colorante alimentario"
    if "pimenton" in a.lower() and "dulce" in a.lower() and " con " not in a.lower():
        return "pimenton dulce"
    if "pimenton" in a.lower() and "picante" in a.lower() and " con " not in a.lower():
        return "pimenton picante"
    if "azafran" in a.lower() and " con " not in a.lower():
        return "azafran"
    if "pimienta" in a.lower() and "negra" in a.lower() and " con " not in a.lower():
        return "pimienta negra"
    if "pimienta" in a.lower() and "blanca" in a.lower() and " con " not in a.lower():
        return "pimienta blanca"
    if "pimienta" in a.lower() and "verde" in a.lower() and " con " not in a.lower():
        return "pimienta verde"
    if "ajo" in a.lower() and "granulado" in a.lower():
        return "ajo en polvo"
    if "ajo" in a.lower() and "polvo" in a.lower():
        return "ajo en polvo"
    if "pinones" in a.lower()and " con " not in a.lower():
        return "pinones"
    if "cebolla" in a.lower() and "crujiente" in a.lower()and " con " not in a.lower():
        return "cebolla frita crujiente"
    if "canela" in a.lower() and " con " not in a.lower(): 
        return "canela"
    if "comino" in a.lower() and " con " not in a.lower(): 
        return "comino"
    if "curry" in a.lower() and " con " not in a.lower() and " al " not in a.lower():
        return "curry"
    if "nuez moscada" in a.lower() and " con " not in a.lower():
        return "nuez moscada"
    if "curcuma" in a.lower() and " con " not in a.lower():
        return "curcuma"
    if "jengibre" in a.lower() and " con " not in a.lower() and " y " not in a.lower() and "zumo" not in a.lower():
        return "jengibre"
    if "clavo" in a.lower() and "grano" in a.lower():
        return "clavo en grano"
    if "vainilla" in a.lower() and " de " not in a.lower() and "sabor" not in a.lower() and "aroma" not in a.lower():
        return "vainilla"
    if "trufas" in a.lower():
        return "trufas"
    if "anis" in a.lower() and " de " not in a.lower() and "sabor" not in a.lower() and "licor" not in a.lower():
        return "anis"
    if "pimientos choriceros" in a.lower():
        return "pimientos choriceros"
    if "sazonador" in a.lower():
        return "sazonador"
    if "mayonesa" in a.lower():
        return "mayonesa"
    if "ketchup" in a.lower():
        return "ketchup"
    if "mostaza" in a.lower() and " con " not in a.lower():
        return "mostaza"
    if "allioli" in a.lower() and " con " not in a.lower():
        return "allioli"
    if "alioli" in a.lower() and " con " not in a.lower():
        return "allioli"
    if "alli oli" in a.lower() and " con " not in a.lower():
        return "allioli"
    if "tomate frito" in a.lower() and " con " not in a.lower():
        return "tomate frito"
    if "salsa" in a.lower() and "barbacoa" in a.lower() and " con " not in a.lower():
        return "salsa barbacoa"
    if "salsa" in a.lower() and "bbq" in a.lower() and " con " not in a.lower():
        return "salsa barbacoa"
    if "salsa" in a.lower() and "bolonesa" in a.lower() and " con " not in a.lower():
        return "salsa bolonesa"
    if "salsa" in a.lower() and "pesto" in a.lower() and " con " not in a.lower():
        return "salsa pesto"
    if "salsa" in a.lower() and "piri piri" in a.lower() and " con " not in a.lower():
        return "salsa piri piri"
    if "salsa" in a.lower() and "chimichurri" in a.lower() and " con " not in a.lower():
        return "salsa chimichurri"
    if "salsa" in a.lower() and "roquefort" in a.lower() and " con " not in a.lower():
        return "salsa roquefort"
    if "salsa" in a.lower() and "carbonara" in a.lower() and " con " not in a.lower():
        return "salsa carbonara"
    if "salsa" in a.lower() and "ranchera" in a.lower() and " con " not in a.lower():
        return "salsa ranchera" 
    if "salsa" in a.lower() and "setas" in a.lower() and " con " not in a.lower():
        return "salsa setas"
    if "salsa" in a.lower() and "teriyaki" in a.lower() and " con " not in a.lower():
        return "salsa teriyaki"
    if "salsa" in a.lower() and "soja" in a.lower() and " con " not in a.lower():
        return "salsa soja"
    if "salsa" in a.lower() and "agridulce" in a.lower() and " con " not in a.lower():
        return "agridulce"
    if "salsa" in a.lower() and "brava" in a.lower() and " con " not in a.lower():
        return "salsa brava"
    if "salsa" in a.lower() and "mexicana" in a.lower() and " con " not in a.lower():
        return "salsa mexicana"
    if "salsa" in a.lower() and "cesar" in a.lower() and " con " not in a.lower():
        return "salsa cesar"
    if "salsa" in a.lower() and "caesar" in a.lower() and " con " not in a.lower():
        return "salsa cesar"
    if "salsa" in a.lower() and " con " not in a.lower() and "barbacoa" not in a.lower() and "bbq" not in a.lower() and "bolonesa" not in a.lower() and "pesto" not in a.lower() and "piri piri" not in a.lower() and "chimichurri" not in a.lower() and "roquefort" not in a.lower() and "carbonara" not in a.lower() and "ranchera" not in a.lower() and "setas" not in a.lower() and"teriyaki" not in a.lower() and "soja" not in a.lower() and "agridulce" not in a.lower() and "brava" not in a.lower() and "mexicana" not in a.lower() and "cesar" not in a.lower() and "caesar" not in a.lower() and "tabasco" not in a.lower() and "queso" not in a.lower():
        return "salsa"
    if "tabasco" in a.lower() and " con " not in a.lower():
        return "tabasco"
    if "bechamel" in a.lower() and " con " not in a.lower():
        return "bechamel"
    if "guacamole" in a.lower():
        return "guacamole"
    if "alino" in a.lower():
        return "alino"
    if "salsa" in a.lower() and "queso" in a.lower() and " con " not in a.lower():
        return "salsa de queso"
    if "mojo" in a.lower() and "canar" in a.lower() and " con " not in a.lower():
        return "mojo canario"
    if "agua" in a.lower() and "micelar" not in a.lower() and "mineral" not in a.lower():
        return "agua otro"
    if "gaseosa" in a.lower():
        return "gaseosa"
    if "isotonica" in a.lower():
        return "bebida isotonica"
    if "bebida energetica" in a.lower():
        return "bebida energetica"
    if "red bull" in a.lower():
        return "bebida energetica"
    if "redbull" in a.lower():
        return "bebida energetica"
    if "monster" in a.lower():
        return "bebida energetica"
    if "gel" in a.lower() and " en " not in a.lower() and "sabor" not in a.lower():
        return "gel de ducha"
    if " cola " in a.lower() and "caballo" not in a.lower():
        return "cocacola"
    if "coca-cola" in a.lower():
        return "cocacola"
    if "limon" in a.lower() and "fanta" in a.lower():
        return "refresco limon"
    if "limon" in a.lower() and "schweppes" in a.lower():
        return "refresco limon"
    if "limon" in a.lower() and "refresco" in a.lower():
        return "refresco limon"
    if "naranja" in a.lower() and "fanta" in a.lower():
        return "refresco naranja"
    if "naranja" in a.lower() and "schweppes" in a.lower():
        return "refresco naranja"
    if "naranja" in a.lower() and "refresco" in a.lower():
        return "refresco naranja"
    if "sprite" in a.lower():
        return "sprite"
    if "7 up" in a.lower():
        return "7 up"
    if "acuarius" in a.lower():
        return "acuarius"
    if "tonica" in a.lower():
        return "tonica"
    if "nestea" in a.lower():
        return "nestea"
    if "refresco" in a.lower() and " te " in a.lower():
        return "nestea"
    if "refresco" in a.lower() and "naranja" not in a.lower() and "cola" not in a.lower() and "tonica" not in a.lower() and "sprite" not in a.lower() and "nestea" not in a.lower() and "te" not in a.lower() and "limon" not in a.lower() and "acuarius" not in a.lower() and "energetic" not in a.lower() and "red bull" not in a.lower() and "redbull" not in a.lower() and "monster" not in a.lower():
        return "refresco otro"
    if "aceitunas" in a.lower() and "negras" not in a.lower():
        return "aceitunas"
    if "aceitunas" in a.lower() and "negras" in a.lower():
        return "aceitunas negras"
    if "banderillas" in a.lower():
        return "banderillas"
    if "penillos" in a.lower():
        return "penillos"
    if "altramuces" in a.lower():
        return "altramuces"
    if "alcaparr" in a.lower():
        return "alcaparras"
    if "cebollitas" in a.lower():
        return "cebollitas en vinagre"
    if "guindilla" in a.lower() and "vinagre" in a.lower() or "encurtid" in a.lower():
        return "guidillas en vinagre"
    if "piparra" in a.lower():
        return "piparras en vinagre"
    if "encurtid" in a.lower() and "banderillas" not in a.lower() and "pepinillos" not in a.lower() and "altramuces" not in a.lower() and "alcaparras" not in a.lower() and "cebollitas" not in a.lower() and "guindillas" not in a.lower()  and "piparras" not in a.lower():
        return "encurtidos otro"
    if "nuez" in a.lower() and "moscada" not in a.lower() and " con " in a.lower() and " de " in a.lower():
        return "nueces"
    if "nueces" in a.lower() and " con " in a.lower() and " de " in a.lower():
        return "nueces"
    if "pistacho" in a.lower() and " con " not in a.lower() and "mix" not in a.lower() and "coctel" not in a.lower() and "cocktail" not in a.lower():
        return "pistachos"
    if "pipas" in a.lower() and " con " not in a.lower() and "mix" not in a.lower() and "coctel" not in a.lower() and "cocktail" not in a.lower():
        return "pipas"
    if "anacardo" in a.lower() and " con " not in a.lower() and "mix" not in a.lower() and "coctel" not in a.lower() and "cocktail" not in a.lower():
        return "anacardos"
    if "avellana" in a.lower() and " con " not in a.lower() and "mix" not in a.lower() and "coctel" not in a.lower() and "cocktail" not in a.lower():
        return "avellanas"
    if "almendra" in a.lower() and " con " not in a.lower() and "mix" not in a.lower() and "coctel" not in a.lower() and "cocktail" not in a.lower():
        return "almendras"
    if "maiz" in a.lower() and "frito" in a.lower() and "mix" not in a.lower() and "coctel" not in a.lower() and "cocktail" not in a.lower():
        return "maiz frito (quicos)"
    if "palomitas" in a.lower() and "mix" not in a.lower() and "coctel" not in a.lower() and "cocktail" not in a.lower():
        return "palomitas"
    if "semillas" in a.lower() and " con " not in a.lower():
        return "semillas"
    if "castanas" in a.lower():
        return "castanas"
    if "peladillas" in a.lower():
        return "peladillas"
    if "frutos secos" in a.lower() and " con " not in a.lower():
        return "frutos secos"
    if "cocktail" in a.lower():
        return "mix aperitivo"
    if "pasas" in a.lower() and " con " not in a.lower():
        return "pasas"
    if "deshidratad" in a.lower():
        return "fruta deshidrata"
    if "datil" in a.lower() and " con " not in a.lower():
        return "datiles"
    if "pan " in a.lower() and "molde" not in a.lower() and "mazapan" not in a.lower():
        return "pan"
    if "mazapan" in a.lower():
        return "mazapan"
    
    if "patatas fritas" in a.lower() and "congelad" not in a.lower():
        return "patatas fritas apetiritivo"
    if "pringles" in a.lower() and "congelad" not in a.lower():
        return "patatas fritas apetiritivo"
    if "nachos" in a.lower() and "salsa" not in a.lower():
        return "nachos"
    if "conos" in a.lower() and "sabor" in a.lower():
        return "patatas fritas apetiritivo otro"
    if "cheetos" in a.lower():
        return "cheetos"
    if "torreznos" in a.lower() or "cortezas" in a.lower():
        return "torreznos"
    if "arroz" in a.lower() and "inflado" not in a.lower():
        return "arroz"
    if "arroz" in a.lower() and "inflado" in a.lower():
        return "arroz inflado"
    if "cous cous" in a.lower():
        return "cous cous"
    if "quinoa" in a.lower():
        return "quinoa"
    if "garbanzo" in a.lower():
        return "garbanzo"
    if "alubia" in a.lower() and "blanca" in a.lower():
        return "alubias blancas"    
    if "alubia" in a.lower() and "pinta" in a.lower():
        return "alubias pinta"       
    if "alubia" in a.lower() and "roja" not in a.lower() and "blanca" not in a.lower():
        return "alubias"
    if "lentejas" in a.lower():
        return "lentejas"
    if "fideo" in a.lower() or "pasta maravilla" in a.lower() or "pasta estrella" in a.lower():
        return "fideos"
    if "fideua" in a.lower():
        return "fideua"
    if "soja texturizada" in a.lower():
        return "soja texturizada"
    if "semola" in a.lower():
        return "semola"
    if "penne" in a.lower() or "pajaritas" in a.lower() or "fusilli" in a.lower() or "tortiglioni" in a.lower() or "macarron" in a.lower() or "pasta tiburon" in a.lower():
        return "macarrones"
    if "spaghetti" in a.lower() or "espaguetti" in a.lower() or "tallarin" in a.lower() or "nidos " in a.lower() or "tagliatelle" in a.lower():
        return "espaguetis"
    if "tortellini" in a.lower() or "ravioli" in a.lower() or "medialunas" in a.lower() or "girasoles" in a.lower():
        return "pasta fresca rellena"
    if "gnocchi" in a.lower(): 
        return "gnocchi"
    if "lasana " in a.lower() and "placa" in a.lower():
        return "pasta para lasana"
    if "lasana " in a.lower() and "placa" not in a.lower():
        return "lasana preparada"
    if "oriental" in a.lower() and "pasta" in a.lower():
        return "pasta oriental"
    if "lasana " in a.lower() and "lamina" in a.lower():
        return "pasta para lasana"
    if "lasana " in a.lower() and "lamina" not in a.lower():
        return "lasana preparada"
    if "oriental" in a.lower() and "fideos" in a.lower():
        return "pasta oriental"
    if "noodles" in a.lower() or "ramen" in a.lower():
        return "pasta oriental"
    if "azucar " in a.lower() and "moreno" not in a.lower() and "glass" not in a.lower() and " con " not in a.lower() and " sin " not in a.lower():
        return "azucar"
    if "azucar " in a.lower() and "moreno" in a.lower() and "glass" not in a.lower() and " con " not in a.lower() and " sin " not in a.lower():
        return "azucar moreno"
    if "edulcorante" in a.lower() or "fructosa" in a.lower() or "sacarina" in a.lower():
        return "edulcorante"
    if "chicle" in a.lower():
        return "chicles"
    if "caramelo" in a.lower() and " con " not in a.lower():
        return "caramelos"
    if "chocolate" in a.lower() and "negro" in a.lower() and " de " not in a.lower():
        return "chocolate negro"
    if "chocolate" in a.lower() and "leche" in a.lower() and " de " not in a.lower():
        return "chocolate con leche"
    if "chocolatina" in a.lower() or "kinder" in a.lower() or "huesitos" in a.lower():
        return "chocolatinas"
    if "barritas" in a.lower() and "chocolate" in a.lower():
        return "chocolatinas"
    if "nocilla" in a.lower() or "nutella" in a.lower() or "crema de cacao" in a.lower():
        return "crema de cacao"
    if "golosinas" in a.lower() or "regaliz" in a.lower() or "chuche" in a.lower():
        return "golosinas"
    if "mermelada" in a.lower() and " con " not in a.lower():
        return "mermelada"
    if "confitura" in a.lower() and " con " not in a.lower():
        return "mermelada"
    if "miel" in a.lower() and " con " not in a.lower():
        return "miel"
    if "turron" in a.lower():
        return "turron"
    if "papilla" in a.lower():
        return "papilla"
    if "preparado lacteo" in a.lower() or "leche de continuacion" in a.lower() or "leche crecimiento" in a.lower() or "leche para lactantes" in a.lower():
        return "leche para bebes"
    if "biberon" in a.lower():
        return "biberon"
    if "chupete" in a.lower():
        return "chupete"
    if "tetina" in a.lower():
        return "tetina"
    if "toallitas" in a.lower() and "bebe" in a.lower():
        return "toallitas bebe"
    if "panal" in a.lower() or "panales" in a.lower():
        return "panales"
    if "leche" in a.lower() and "semidesnatada" in a.lower() and "avena" not in a.lower() and "soja" not in a.lower() and "almendra" not in a.lower():
        return "leche semidesnatada"
    if "leche" in a.lower() and "entera" in a.lower() and "avena" not in a.lower() and "soja" not in a.lower() and "almendra" not in a.lower():
        return "leche entera"
    if "leche" in a.lower() and  "avena" in a.lower() and "soja" not in a.lower() and "almendra" not in a.lower():
        return "leche de avena"
    if "leche" in a.lower() and  "avena" not in a.lower() and "soja" in a.lower() and "almendra" not in a.lower():
        return "leche de soja" 
    if "leche" in a.lower() and  "avena" not in a.lower() and "soja" not in a.lower() and "almendra" in a.lower():
        return "leche almendras"
    if "carpaccio" in a.lower(): 
        return "carpaccio"
    if "champu" in a.lower():
        return "champu"
    if "cerveza" in a.lower():
        return "cerveza"
    if "vermouth" in a.lower():
        return "vermouth"
    if "ginebra" in a.lower():
        return "ginebra"
    if "cava " in a.lower():
        return "cava"
    if "zumo" in a.lower():
        return "zumo"
    if "vino" in a.lower() and "espumoso" in a.lower():
        return "vino espumoso"
    if "sangria" in a.lower():
        return "sangria"  
    if "tinto de verano" in a.lower():
        return "tinto de verano"
    if "vino" in a.lower() and "dulce" in a.lower():
        return "vino dulce"
    if "vino" in a.lower() and "tinto" in a.lower()and "verano" not in a.lower():
        return "vino tinto"    
    if "albarino" in a.lower():
        return "vino D.O. albarino"
    if "albarino" in a.lower():
        return "albarino"
    if "d.o. rueda" in a.lower():
        return "vino D.O. Rueda"
    if "vino" in a.lower() and "rosado" in a.lower():
        return "vino rosado"
    if "d.o. ribera de duero" in a.lower():
        return "vino D.O. Ribera del Duero "
    if "d.o. ribera del duero" in a.lower():
        return "vino D.O. Ribera del Duero "
    if "d.o. rioja" in a.lower():
        return "vino D.O. Rioja "
    if "vino" in a.lower() and "carton" in a.lower() and "blanco" in a.lower():
        return "brick de vino blanco"
    if "vino" in a.lower() and "brick" in a.lower() and "blanco" in a.lower():
        return "brick de vino blanco"
    if "vino" in a.lower() and "carton" in a.lower() and "tinto" in a.lower():
        return "brick de vino tinto"
    if "vino" in a.lower() and "brick" in a.lower() and "tinto" in a.lower():
        return "brick de vino tinto"
    if "vino" in a.lower() and "carton" in a.lower() and "rosado" in a.lower():
        return "brick de vino rosado"
    if "vino" in a.lower() and "brick" in a.lower() and "rosado" in a.lower():
        return "brick de vino rosado"
    if "brandy" in a.lower() and "con " not in a.lower() and "al " not in a.lower():
        return "brandy"
    if "whisky" in a.lower() and "con " not in a.lower() and "al " not in a.lower():
        return "whisky"
    if "whiskey" in a.lower() and "con " not in a.lower() and "al " not in a.lower():
        return "whisky"
    if "ron " in a.lower() and "anejo" in a.lower():
        return "ron"
    if "ron " in a.lower() and "blanco" in a.lower():
        return "ron blanco"
    if "malibu" in a.lower():
        return "malibu"
    if "limoncello" in a.lower() and "con " not in a.lower() and "al " not in a.lower():
        return "limoncello"
    if "licor" in a.lower() and "con " not in a.lower() and "al " not in a.lower():
        return "licor"
    if "vodka" in a.lower() and "con " not in a.lower() and "al " not in a.lower():
        return "vodka"
    if "licor de hierbas" in a.lower() and "con " not in a.lower() and "al " not in a.lower():
        return "licor de hierbas"
    if "aguardiente" in a.lower() and "con " not in a.lower() and "al " not in a.lower():
        return "aguardiente"
    if "cointreau" in a.lower() and "con " not in a.lower() and "al " not in a.lower():
        return "cointreau"
    if "pacharan" in a.lower() and "con " not in a.lower() and "al " not in a.lower():
        return "pacharan"
    if "amaretto" in a.lower() and "con " not in a.lower() and "al " not in a.lower():
        return "amaretto"
    if "tequila" in a.lower() and "con " not in a.lower() and "al " not in a.lower():
        return "tequila"
    if "ponche" in a.lower() and "con " not in a.lower() and "al " not in a.lower():
        return "ponche"
    if "cocktail" in a.lower() and "sin alcohol" in a.lower():
        return "cocktail sin alcohol"
    if "sidra" in a.lower() and "con " not in a.lower() and "a la " not in a.lower():
        return "sidra"
    if "mosto " in a.lower(): 
        return "zumo"
    if "nectar " in a.lower():
        return "zumo"
    if "cafe " in a.lower() and "capsula" in a.lower():
        return "cafe en capsulas"
    if "cafe " in a.lower() and "descafeinado" in a.lower():
        return "cafe descafeinado"
    if "cafe " in a.lower() and "capsula" not in a.lower():
        return "cafe"
    if "infusion " in a.lower() and "manzanilla" not in a.lower() and "cola de caballo" not in a.lower() and "menta poleo" not in a.lower() and "te" not in a.lower():
        return "infusiones otras"
    if "infusion " in a.lower() and "manzanilla" in a.lower() and "cola de caballo" not in a.lower() and "menta poleo" not in a.lower() and "te" not in a.lower():
        return "manzanilla"
    if "infusion " in a.lower() and "manzanilla" not in a.lower() and "cola de caballo" in a.lower() and "menta poleo" not in a.lower() and "te" not in a.lower():
        return "cola de caballo"
    if "infusion " in a.lower() and "manzanilla" not in a.lower() and "cola de caballo" not in a.lower() and "menta poleo" in a.lower() and "te" not in a.lower():
        return "menta poleo"
    if "infusion " in a.lower() and "manzanilla" not in a.lower() and "cola de caballo" not in a.lower() and "menta poleo" not in a.lower() and "te" in a.lower():
        return "te"
    if "compango" in a.lower():
        return "compango"
    if "morcilla" in a.lower(): 
        return "morcilla"
    if "espinazo de cerdo" in a.lower():
        return "espinazo de cerdo"
    if "pavo" in a.lower() and "filete" in a.lower():
        return "filetes de pavo"
    if "pavo" in a.lower() and "chulet" in a.lower():
        return "chuletas de pavo"
    if "pavo" in a.lower() and "solomillo" in a.lower():
        return "solomillo de pavo"
    if "pavo" in a.lower() and "brochet" in a.lower():
        return "brochetas de pavo"
    if "pavo" in a.lower() and "filete" not in a.lower():
        return "pechuga de pavo"
    if "pavo" in a.lower() and "taco" in a.lower():
        return "tacos de pavo"
    if "pavo" in a.lower() and "pierna" in a.lower():
        return "pierna de pavo"
    if "codornices" in a.lower():
        return "codornices"    
    if "pechuga" in a.lower() and "pollo" in a.lower() and "filete" not in a.lower() and "pavo" not in a.lower() and "entera" in a.lower():
        return "pechuga de pollo entera"
    if "pechuga" in a.lower() and "pollo" in a.lower() and "filete" in a.lower() and "pavo" not in a.lower():
        return "pechuga de pollo en filetes"
    if "contramuslo" in a.lower() and "pollo" in a.lower():
        return "contramuslo de pollo"
    if "solomillo" in a.lower() and "pollo" in a.lower():
        return "solomillo de pollo"
    if "muslo" in a.lower() and "pollo" in a.lower() and "contramuslo" not in a.lower():
        return "muslo de pollo"
    if "alas" in a.lower() and "pollo" in a.lower():
        return "alitas de pollo"
    if "alitas" in a.lower() and "pollo" in a.lower():
        return "alitas de pollo"
    if "jamoncitos" in a.lower() and "pollo" in a.lower():
        return "jamoncitos de pollo"
    if "costillas" in a.lower() and "cerdo" in a.lower():
        return "costillas de cerdo"
    if "costillar" in a.lower() and "cerdo" in a.lower():
        return "costillas de cerdo"
    if "cerdo" in a.lower() and "lomo" in a.lower():
        return "lomitos de cerdo"
    if "cerdo" in a.lower() and "carrillada" in a.lower():
        return "carrillada de cerdo"
    if "cerdo" in a.lower() and "chulet" in a.lower():
        return "chuletas de cerdo"
    if "cerdo" in a.lower() and "tacos" in a.lower():
        return "tacos de cerdo"
    if "panceta" in a.lower():
        return "panceta de cerdo"
    if "sanjacobos" in a.lower():
        return "san jacobos"
    if "san jacobos" in a.lower():
        return "san jacobos"
    if "flauta" in a.lower() and "queso" in a.lower() and "bacon" in a.lower():
        return "fauta de queso y bacon"
    if "secreto" in a.lower() or "secreto de cerdo" in a.lower()or "secreto iberico" in a.lower():
        return "secreto de cerdo"
    if "manteca" in a.lower() and "cerdo" in a.lower():
        return "manteca de cerdo"
    if "filete" in a.lower() and "cerdo" in a.lower() and "lomo" not in a.lower() and "higado" not in a.lower():
        return "filetes de cerdo"
    if "codillo" in a.lower() and "cerdo" in a.lower():
        return "codillo de cerdo"
    if "filete" in a.lower() and "cerdo" in a.lower() and "lomo" not in a.lower() and "higado" in a.lower():
        return "filetes de cerdo"
    if "pincho" in a.lower() and "cerdo" in a.lower():
        return "pinchos de cerdo"
    if "presa" in a.lower() and "cerdo" in a.lower():
        return "presa de cerdo"
    if "solomillo" in a.lower() and "cerdo" in a.lower():
        return "solomillo de cerdo"
    if "cochinillo" in a.lower():
        return "cochinillo"
    if "conejo" in a.lower():
        return "conejo"
    if "cordero" in a.lower() and "chuletas" in a.lower():
        return "chuletas de cordero"
    if "cordero" in a.lower() and "chuletitas" in a.lower():
        return "chuletas de cordero"
    if "cordero" in a.lower() and "chuletillas" in a.lower():
        return "chuletas de cordero"
    if "cordero" in a.lower() and "higado" in a.lower():
        return "higado de cordero"
    if "cordero" in a.lower() and "higado" not in a.lower() and "chuletas" not in a.lower() and "chuletitas" not in a.lower() and "chuletillas" not in a.lower():
        return "cordero"
    if "longaniza" in a.lower() and "fresca" in a.lower():
        return "longaniza fresca"
    if "butifarra" in a.lower() and "fresca" in a.lower():
        return "butifarra fresca"
    if "chistorra" in a.lower(): 
        return "chistorra"
    if "embutido" in a.lower():
        return "embutido"
    if "burger" in a.lower() and "pollo" in a.lower():
        return "hamburguesa de pollo"
    if "hamburguesa" in a.lower() and "pollo" in a.lower():
        return "hamburguesa de pollo"
    if "burger" in a.lower() and "vacuno" in a.lower():
        return "hamburguesa de vacuno"
    if "hamburguesa" in a.lower() and "vacuno" in a.lower():
        return "hamburguesa de vacuno"
    if "burger" in a.lower() and "pavo" in a.lower():
        return "hamburguesa de pavo"
    if "hamburguesa" in a.lower() and "pavo" in a.lower():
        return "hamburguesa de pavo"
    if "burger" in a.lower() and "vegetariana" in a.lower():
        return "hamburguesa de vegetariana"
    if "hamburguesa" in a.lower() and "vegetariana" in a.lower():
        return "hamburguesa de vegetariana"
    if "burger" in a.lower() and "vegana" in a.lower():
        return "hamburguesa de vegetariana"
    if "hamburguesa" in a.lower() and "vegana" in a.lower():
        return "hamburguesa de vegetariana"
    if "carne picada" in a.lower() and "cerdo" in a.lower() and "vacuno" in a.lower():
        return "carne picada mix cerdo y vacuno"
    if "carne picada" in a.lower() and "cerdo" not in a.lower() and "vacuno" in a.lower():
        return "carne picada vacuno"
    if "carne picada" in a.lower() and "cerdo" in a.lower() and "vacuno" not in a.lower():
        return "carne picada cerdo"
    if "carne picada" in a.lower() and "pollo" in a.lower() and "pavo" in a.lower():
        return "carne picada mix pollo y pavo"
    if "carne picada" in a.lower() and "pollo" not in a.lower() and "pavo" in a.lower():
        return "carne picada pavo"
    if "carne picada" in a.lower() and "pollo" in a.lower() and "pavo" not in a.lower():
        return "carne picada pollo"
    if "albondiga" in a.lower():
        return "albondigas"
    if "ternera" in a.lower() and "filete" in a.lower() and "lomo" not in a.lower() and "higado" not in a.lower():
        return "filetes de ternera"
    if "vacuno" in a.lower() and "filete" in a.lower()and "lomo" not in a.lower() and "higado" not in a.lower():
        return "filetes de ternera"  
    if "vacuno" in a.lower() and "tacos" in a.lower():
        return "tacos de vacuno"
    if "vacuno" in a.lower() and "lomo" in a.lower():
        return "lomo de vacuno" 
    if "vacuno" in a.lower() and "solomillo" in a.lower():
        return "solomillo de vacuno"
    if "vacuno" in a.lower() and "entrecot" in a.lower():
        return "entrecot de vacuno"
    if "vacuno" in a.lower() and "churrasco" in a.lower():
        return "churrasco de vacuno"
    if "vacuno" in a.lower() and "higado" in a.lower()and "filete" in a.lower():
        return "filetes de higado de vacuno" 
    if "vacuno" in a.lower() and "chuleton" in a.lower():
        return "chuleton de vacuno"
    if "vacuno" in a.lower() and "callos" in a.lower():
        return "challos de vacuno"
    if "croquetas" in a.lower():
        return "croquetas"
    if "pizza" in a.lower():
        return "pizza"
    if "empanada de " in a.lower():
        return "empanada"
    if "cereales" in a.lower():
        return "cereales"
    if "tortitas" in a.lower() and "arroz" in a.lower():
        return "tortitas de arroz"
    if "pavo" in a.lower() and "lonchas" in a.lower():
        return "fiambre de pavo en lonchas"
    if "pavo" in a.lower() and "al corte" in a.lower():
        return "fiambre de pavo en lonchas"
    if "pavo" in a.lower() and "dados" in a.lower():
        return "fiambre de pavo en lonchas"
    if "jamon" in a.lower() and "cocido" in a.lower():
        return "jamon cocido"
    if "chorizo" in a.lower() and "con " not in a.lower():
        return "chorizo"
    if "salchichon" in a.lower() and "con " not in a.lower():
        return "salchichon"
    if "queso" in a.lower() and "con " not in a.lower():
        return "queso"
    if "pate" in a.lower():
        return "pate"
    if "fuet" in a.lower() and "con " not in a.lower():
        return "fuet"
    if "menestra" in a.lower() and "congel" not in a.lower():
        return "menestra congelada"
    if "judias verdes" in a.lower() and "congel" not in a.lower():
        return "judias verdes congeladas"
    if "guisantes" in a.lower() and "congel" not in a.lower():
        return "guisantes congelados"    
    if "helado" in a.lower():
        return "helado"
    if "hielo" in a.lower():
        return "hielo"
    if "tarta" in a.lower():
        return "tarta"
    if "preservativos" in a.lower():
        return "preservativos"
    if "manzana" in a.lower() and "sabor" not in a.lower() and "aroma" not in a.lower() and "nectar" not in a.lower() and "zumo" not in a.lower() and "yogur" not in a.lower():
        return "manzanas"
    if "mandarina" in a.lower() and "sabor" not in a.lower() and "aroma" not in a.lower() and "nectar" not in a.lower() and "zumo" not in a.lower() and "yogur" not in a.lower():
        return "mandarinas"
    if "platano" in a.lower() and "sabor" not in a.lower() and "aroma" not in a.lower() and "nectar" not in a.lower() and "zumo" not in a.lower() and "yogur" not in a.lower():
        return "platano"
    if "banana" in a.lower() and "sabor" not in a.lower() and "aroma" not in a.lower() and "nectar" not in a.lower() and "zumo" not in a.lower() and "yogur" not in a.lower():
        return "banana"
    if "pina " in a.lower() and "sabor" not in a.lower() and "aroma" not in a.lower() and "nectar" not in a.lower() and "zumo" not in a.lower() and "yogur" not in a.lower():
        return "pina"
    if "uva" in a.lower() and "sabor" not in a.lower() and "aroma" not in a.lower() and "nectar" not in a.lower() and "zumo" not in a.lower() and "yogur" not in a.lower():
        return "uvas"
    if "melocoton" in a.lower() and "sabor" not in a.lower() and "aroma" not in a.lower() and "nectar" not in a.lower() and "zumo" not in a.lower() and "yogur" not in a.lower():
        return "melocoton"
    if "papaya" in a.lower() and "sabor" not in a.lower() and "aroma" not in a.lower() and "nectar" not in a.lower() and "zumo" not in a.lower() and "yogur" not in a.lower():
        return "papaya"
    if "kiwi" in a.lower() and "sabor" not in a.lower() and "aroma" not in a.lower() and "nectar" not in a.lower() and "zumo" not in a.lower() and "yogur" not in a.lower():
        return "kiwis"
    if "mango" in a.lower() and "sabor" not in a.lower() and "aroma" not in a.lower() and "nectar" not in a.lower() and "zumo" not in a.lower() and "yogur" not in a.lower():
        return "mango"
    if "naranja" in a.lower() and "sabor" not in a.lower() and "aroma" not in a.lower() and "nectar" not in a.lower() and "zumo" not in a.lower() and "yogur" not in a.lower():
        return "naranjas"
    if "tomate" in a.lower() and "frito" not in a.lower() and "sabor" not in a.lower() and "aroma" not in a.lower() and "nectar" not in a.lower() and "zumo" not in a.lower() and "yogur" not in a.lower():
        return "tomate"
    if "zanahoria" in a.lower() and "sabor" not in a.lower() and "aroma" not in a.lower() and "nectar" not in a.lower() and "zumo" not in a.lower() and "yogur" not in a.lower():
        return "zanahoria"
    if "frambuesa" in a.lower() and "sabor" not in a.lower() and "aroma" not in a.lower() and "nectar" not in a.lower() and "zumo" not in a.lower() and "yogur" not in a.lower():
        return "frambuesas"
    if "mora" in a.lower() and "sabor" not in a.lower() and "aroma" not in a.lower() and "nectar" not in a.lower() and "zumo" not in a.lower() and "yogur" not in a.lower():
        return "moras"
    if "caqui" in a.lower() and "sabor" not in a.lower() and "aroma" not in a.lower() and "nectar" not in a.lower() and "zumo" not in a.lower() and "yogur" not in a.lower():
        return "caquis"    
    if "lechuga" in a.lower():
        return "lechuga"
    if "endivias" in a.lower():
        return "endivias"
    if "ensalada" in a.lower() and "para " not in a.lower():
        return "ensalada"
    if "calabacin" in a.lower() and  "crema" not in a.lower() and "pure" not in a.lower() and " con " not in a.lower():
        return "calabacin"
    if "berenjena" in a.lower() and  "crema" not in a.lower() and "pure" not in a.lower() and " con " not in a.lower() and "rellena" not in a.lower():
        return "berenjena"
    if "pimiento" in a.lower() and "verde" in a.lower() and  "crema" not in a.lower() and "pure" not in a.lower() and " con " not in a.lower() and "rellen" not in a.lower():
        return "pimientos verdes"
    if "pimiento" in a.lower() and "rojo" in a.lower() and  "crema" not in a.lower() and "pure" not in a.lower() and " con " not in a.lower() and "rellen" not in a.lower():
        return "pimientos rojos"
    if "pimiento" in a.lower() and "piquillo" in a.lower() and  "crema" not in a.lower() and "pure" not in a.lower() and " con " not in a.lower() and "rellen" not in a.lower():
        return "pimientos de piquillo"
    if "esparrago" in a.lower() and "trigueros" in a.lower() and  "crema" not in a.lower() and "pure" not in a.lower() and " con " not in a.lower() and "rellen" not in a.lower():
        return "esparragos trigueros"
    if "espinaca" in a.lower() and "fresca" in a.lower():
        return "espinacas frescas"
    if "espinaca" in a.lower() and "congel" in a.lower():
        return "espinacas congeladas"
    if "aguacate" in a.lower() and "con " not in a.lower():
        return "aguacate"
    if "cebolla" in a.lower() and  "crema" not in a.lower() and "pure" not in a.lower() and " con " not in a.lower() and "rellen" not in a.lower():
        return "cebolla"
    if "ajo" in a.lower() and  "crema" not in a.lower() and "pure" not in a.lower() and " con " not in a.lower() and "rellen" not in a.lower():
        return "ajo"
    if "chalota" in a.lower() and  "crema" not in a.lower() and "pure" not in a.lower() and " con " not in a.lower() and "rellen" not in a.lower():
        return "chalota"
    
    if "sardinillas" in a.lower() and "aceite" in a.lower() and "fresco" not in a.lower():
        return "lata sardinillas en aceite"
    if "atun" in a.lower() and "natural" in a.lower() and "fresco" not in a.lower():
        return "lata atun al natural"
    if "atun" in a.lower() and "aceite" in a.lower() and "fresco" not in a.lower():
        return "lata atun al aceite"
    if "maiz" in a.lower() and "dulce" in a.lower() and "fresco" not in a.lower():
        return "maiz dulce"
    if "atun" in a.lower() and "congel" in a.lower():
        return "atun congelado"
    if "sepia" in a.lower() and "congel" in a.lower():
        return "sepia congelada"
    
    if "yogur de " in a.lower() and "natural" not in a.lower() and "griego" not in a.lower() and "bifidus" not in a.lower():
        return "yogures de sabores"   
    if "yogur" in a.lower()and "natural" in a.lower() and "griego" not in a.lower():
        return "yogur natural"
    if "yogur" in a.lower() and "griego" in a.lower():
        return "yogur griego"
    if "yogur" in a.lower() and "bifidus" in a.lower():
        return "yogur bifidus"
    
    
    
    
    if "desodorante" in a.lower():
        return "desodorante"
    if "dentifrico" in a.lower():
        return "dentifrico"
    if "enjuague bucal" in a.lower():
        return "enjuague bucal"
    if "colonia" in a.lower():
        return "colonia"
    if "tampones" in a.lower():
        return "tampones"
    if "compresas" in a.lower():
        return "compresas"
    if "crema" in a.lower() and "hidratante" in a.lower():
        return "crema hidratante"
    if "cepillo de dientes" in a.lower():
        return "cepillo de dientes"
    
    
    if "pure de" in a.lower() and "infantil" not in a.lower():
        return "pure"
    if "gazpacho" in a.lower():
        return "gazpacho"
    if "salmorejo" in a.lower():
        return "salmorejo"
    if "detergente" in a.lower():
        return "detergente"
    if "suavizante" in a.lower() and "ropa" in a.lower():
        return "suavizante"
    
 
    else:
        return "nada"

# %%
mer_cat=mer

# %%
mer_cat["categoria"]=mer_cat.producto.apply(categorias)

# %%
mer_cat = mer_cat.loc[(mer_cat["categoria"]!= "nada")]

# %%
mer_cat.shape
# Out:
# (3654, 6)

# %%
carr_cat=carr2
carr_cat1=carr

# %%
carr_cat["categoria"]=carr_cat.producto.apply(categorias)
carr_cat1["categoria"]=carr_cat1.producto.apply(categorias)

# %%
carr_cat = carr_cat.loc[(carr_cat["categoria"]!= "nada")]
carr_cat1 = carr_cat1.loc[(carr_cat1["categoria"]!= "nada")]

# %%
print(carr_cat1.shape, carr_cat.shape)
# Out:
# (652, 7) (3285, 7)

# %%
dia_cat=dia
dia_cat1=dia1
dia_cat2=dia2

# %%
dia_cat["categoria"]=dia_cat.producto.apply(categorias)
dia_cat1["categoria"]=dia_cat1.producto.apply(categorias)
dia_cat2["categoria"]=dia_cat2.producto.apply(categorias)

# %%
dia_cat = dia_cat.loc[(dia_cat["categoria"]!= "nada")]
dia_cat1 = dia_cat1.loc[(dia_cat1["categoria"]!= "nada")]
dia_cat2 = dia_cat2.loc[(dia_cat2["categoria"]!= "nada")]

# %%
print(dia_cat.shape,dia_cat1.shape, dia_cat2.shape)
# Out:
# (3614, 7) (18, 6) (15, 6)

# %%
mer_cat["supermercado"]="mercadona"
# Out:
# <ipython-input-238-a214a04055fc>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mer_cat["supermercado"]="mercadona"

# %%
mer_cat.tail()
# Out:
#       Unnamed: 0                                          producto  precio  \
# 6926        6926  Nectar de pomelo Hacendado sin azucares anadidos    1.10
# 6927        6927    Nectar guayaba Hacendado sin azucares anadidos    1.05
# 6928        6928    Nectar de pera Hacendado sin azucares anadidos    0.95
# 6929        6929                          Zumo de pomelo Hacendado    1.30
# 6930        6930               Zumo de manzana seleccion Hacendado    1.36
#
#       cantidad medida categoria supermercado
# 6926       1.0      L      zumo    mercadona
# 6927       1.0      L      zumo    mercadona
# 6928       1.0      L      zumo    mercadona
# 6929       1.0      L      zumo    mercadona
# 6930       1.0      L      zumo    mercadona

# %%
carr_cat["supermercado"]="carrefour"
carr_cat1["supermercado"]="carrefour"
# Out:
# <ipython-input-240-a902eec37313>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   carr_cat["supermercado"]="carrefour"
# <ipython-input-240-a902eec37313>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   carr_cat1["supermercado"]="carrefour"

# %%
dia_cat["supermercado"]="dia"
dia_cat1["supermercado"]="dia"
dia_cat2["supermercado"]="dia"
# Out:
# <ipython-input-241-11920fc4f5d0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dia_cat["supermercado"]="dia"
# <ipython-input-241-11920fc4f5d0>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dia_cat1["supermercado"]="dia"
# <ipython-input-241-11920fc4f5d0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
dia_cat1.head()
# Out:
#    Unnamed: 0                                           producto  precio  \
# 0           0     DIA DULCE NOEL surtido de mazapan caja 300 gr     2.09
# 3           3           DIA EL CENCERRO queso curado cuna 300 gr    1.99
# 4           4   DIA EL CENCERRO queso curado cortado cuna 250 gr    2.21
# 6           6           VOLL-DAMM cerveza doble malta lata 33 cl    0.72
# 7           7  VOLL-DAMM cerveza doble malta pack 6 botellas ...    3.95
#
#    cantidad medida categoria supermercado
# 0     0.300     kg   mazapan          dia
# 3     0.300     kg     queso          dia
# 4     0.250     kg     queso          dia
# 6     0.330      L   cerveza          dia
# 7     1.502      L   cerveza          dia

# %%
carr_cat1.head()
# Out:
#    Unnamed: 0                                           producto  precio  \
# 0           0  Leche semidesnatada Central Lechera Asturiana ...    0.79
# 1           1   Leche entera Central Lechera Asturiana brik 1 l.    0.79
# 2           2  Tomate frito Solis sin gluten y sin lactosa pa...    1.93
# 4           4  Yogur griego con stracciatella Danone Oikos si...    2.12
# 5           5  Leche semidesnatada Central Lechera Asturiana ...    0.79
#
#    cantidad medida  cantidad_            categoria supermercado
# 0     1.000      L      1.000  leche semidesnatada    carrefour
# 1     1.000      L      1.000         leche entera    carrefour
# 2     0.919     kg      0.919         tomate frito    carrefour
# 4     0.440     kg      0.440         yogur griego    carrefour
# 5     1.000      L      1.000  leche semidesnatada    carrefour

# %%
carr_cat_todo=pd.concat([carr_cat, carr_cat1], ignore_index=True)
carr_cat_todo.head()
# Out:
#    Unnamed: 0                                           producto  precio  \
# 0           1        Aceite de oliva virgen extra Carrefour 1 l.    3.95
# 1           2                    Sal marina fina Carrefour 1 kg.    0.22
# 2           3  Yogur de fresa. de macedonia. de limon y de fr...    1.80
# 3           4       Aceite de oliva suave 0.4ÃÂº Carrefour 1 l.    3.20
# 4           7  Aceitunas verdes rellenas de anchoa Carrefour ...    1.99
#
#    cantidad medida  cantidad_                     categoria supermercado
# 0      1.00      L       1.00  aceite de oliva virgen extra    carrefour
# 1      1.00     kg       1.00                      sal fina    carrefour
# 2      2.00     kg       2.00            yogures de sabores    carrefour
# 3      1.00      L       1.00               aceite de oliva    carrefour
# 4      0.45     kg       0.45                     aceitunas    carrefour

# %%
carr_cat_todo.drop("Unnamed: 0", axis=1, inplace=True)

dia_cat.drop("Unnamed: 0", axis=1, inplace=True)
dia_cat1.drop("Unnamed: 0", axis=1, inplace=True)
dia_cat2.drop("Unnamed: 0", axis=1, inplace=True)

mer_cat.drop("Unnamed: 0", axis=1, inplace=True)
# Out:
# /home/silviarico/.local/lib/python3.8/site-packages/pandas/core/frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
mer_cat.head()
# Out:
#                                             producto  precio  cantidad medida  \
# 0                    Aceite de oliva 0.4Âº Hacendado   15.50      5.00      L
# 1                    Aceite de oliva 0.4Âº Hacendado    3.20      1.00      L
# 2             Aceite de oliva virgen extra Hacendado   11.00      3.00      L
# 3             Aceite de oliva virgen extra Hacendado    3.95      1.00      L
# 4  Aceite de oliva virgen extra Hacendado Gran Se...    4.10      0.75      L
#
#                       categoria supermercado
# 0               aceite de oliva    mercadona
# 1               aceite de oliva    mercadona
# 2  aceite de oliva virgen extra    mercadona
# 3  aceite de oliva virgen extra    mercadona
# 4  aceite de oliva virgen extra    mercadona

# %%
mer_cat.to_csv("mer_cat.csv")
carr_cat_todo.to_csv("carr_cat.csv")
dia_cat.to_csv("dia_cat.csv")
dia_cat1.to_csv("dia18_cat.csv")
dia_cat2.to_csv("dia15_cat.csv")
