# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import re
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
lista_merc=[{"Aceite, vinagre y sal":112},{"Especias":115},{"Mayonesa, ketchup y mostaza":116},{"Otras salsas":117},
           {"Agua":156},{"Isotónico y energético":163},{"Refresco de cola":158},{"Refresco de naranja y de limón":159},
           {"Tónica y bitter":161},{"Refresco de té y sin gas":162}, {"Aceitunas y encurtidos":135},{"Frutos secos y fruta desecada":133},
           {"Patatas fritas y snacks":132}, {"Arroz":118},{"Legumbres":121},{"Pasta y fideos":120},{"Azúcar y edulcorante":89},
           {"Chicles y caramelos":95},{"Chocolate":92},{"Golosinas":97},{"Mermelada y miel":90},{"Turrones":833},{"Alimentación infantil":216},{"Biberón, chupete y menaje":219},
           {"Higiene y cuidado bebe":218},{"Toallitas y pañales":217},{"Cerveza":164},{"Cerveza sin alcohol":166},{"Licores":181},{"Sidra y cava":174},
           {"Tinto de verano y sangría":168},{"Vino blanco":170},{"Vino lambrusco y espumoso":173},{"Vino rosado":171},{"Vino tinto":169},{"Cacao soluble y chocolate a la taza":86},
           {"Café cápsula y monodosis":81},{"Café molido y en grano":83},{"Café soluble y otras bebidas":84},{"Té e infusiones":88},{"Arreglos carne":46},{"Aves y pollo":38},{"Carne congelada":47},
           {"Cerdo":37},{"Conejo y cordero":42},{"Embutido":43},{"Hamburguesas y picadas":44},{"Vacuno":40},{"Empanados y elaborados carne":45},{"Cereales":78},{"Galletas":80},{"Tortitas":79},{"Aves y jamón cocido":48},
           {"Bacón y salchichas":52},{"Chopped y mortadela":49},{"Embutido curado":51},{"Jamón serrano":50},{"Paté y sobrasada":58},{"Queso curado, semicurado y tierno":54},{"Queso lonchas, rallado y en porciones":56},{"Queso untable y fresco":53},
           {"Arroz y pasta congelado":147},{"Carne congelado":148},{"Helados":154},{"Hielo":155},{"Marisco congelado":150},{"Pescado congelado":149},{"Pizzas congeladas":151},{"Rebozados congelados":884},{"Tartas y churros congelados":152},{"Verdura congelados":145},
           {"Atún y otras conservas de pescado":122},{"Berberechos y mejillones":123},{"Conservas de verdura y frutas":127},{"Gazpacho y cremas":130},{"Sopa y caldo":129},{"Tomate conserva":126},
           {"Acondicionador y mascarilla":201},{"Champu":199},{"Coloración cabello":203},{"Fijación cabello":202},{"Peines y accesorios":205},
           {"Afeitado y cuidado para hombre":192},{"Afeitado y cuidado para hombre":189},{"Cuidado e higiene facial":185},{"Depilación":191},{"Desodorante":188},{"Gel y jabón de manos":187},{"Higiene bucal":186},{"Higiene íntima":190},{"Manicura y pedicura":194},{"Manicura y pedicura":782},{"Perfume y colonia":196},{"Protector solar y aftersun":198},
           {"Fitoterapia":213},{"Parafarmacia":214},
           {"Fruta":27},{"Lechuga y ensalada preparada":28},{"Verdura":29},{"Huevos":77},{"Leche y bebidas vegetales":72},{"Mantequilla y margarina":75},
           {"Detergente y suavizante ropa":226},{"Estropajo, bayeta y guantes":237},{"Insecticida y ambientador":241},{"Lejía y líquidos fuertes":234},{"Limpiacristales":235},{"Limpiahogar y friegasuelos":233},{"Limpieza baño y WC":231},{"Limpieza cocina":230},{"Limpieza muebles y multiusos":232},{"Limpieza vajilla":229},{"Menaje y conservación de alimentos":243},{"Papel higiénico y celulosa":238},{"Pilas y bolsas de basura":239},{"Utensilios de limpieza y calzado":244},
           {"Bases de maquillaje y corrector":206},{"Colorete y polvos":207},{"Labios":208},{"Ojos":210},{"Pinceles y brochas":212},
           {"Marisco":32},{"Pescado congelado":34},{"Pescado en bandeja":33},{"Pescado Fresco":31},{"Pescado Salazones y ahumados":36},{"sushi":789},
           {"Gato":222},{"Perro":221},{"Pez y otros":225},
           {"Bollería de horno":65},{"Bollería envasada":66},{"Harina y preparado repostería":69},{"Pan de horno":59},{"Pan de molde y otras especialidades":60},{"Pan tostado y rallado":62},{"Picos, rosquilletas y picatostes":64},{"Bollería de horno":65},{"Bollería envasada":66},{"Harina y preparado repostería":69},{"Pan de horno":59},{"Pan de molde y otras especialidades":60},{"Pan tostado y rallado":62},{"Picos, rosquilletas y picatostes":64},{"Tartas y pasteles":68},{"Velas y decoración":71},
           {"Pizzas":138},{"Platos preparados calientes":140},{"Platos preparados fríos":142},
           {"Bifidus":105},{"Flan y natillas":110},{"Gelatina y otros postres":111},{"Postres de soja":106},{"Yogures desnatados":103},{"Yogures griegos":109},{"Yogures líquidos":108},{"Yogures naturales y sabores":104},{"Yogures y postres infantiles":107},
           {"Zumo fruta variada":99},{"Melocotón y piña":100},{"Naranja":143},{"Tomate y otros sabores":98}]

# %%
cat=[]
for i in lista_merc:
    x=list(i.keys())
    cat.append(x)

# %%
flat=[]
flat1=[]
for i in cat:
    for x in i:
        flat.append(x)
for a in range(len(flat)):
        flat[a].split(sep=",")
        flat[a].split(sep="y")
        flat1.append(flat[a])

flat1
# Out:
# ['Aceite, vinagre y sal',
#  'Especias',
#  'Mayonesa, ketchup y mostaza',
#  'Otras salsas',
#  'Agua',
#  'Isotónico y energético',
#  'Refresco de cola',
#  'Refresco de naranja y de limón',
#  'Tónica y bitter',
#  'Refresco de té y sin gas',
#  'Aceitunas y encurtidos',
#  'Frutos secos y fruta desecada',
#  'Patatas fritas y snacks',
#  'Arroz',
#  'Legumbres',
#  'Pasta y fideos',
#  'Azúcar y edulcorante',
#  'Chicles y caramelos',
#  'Chocolate',
#  'Golosinas',
#  'Mermelada y miel',
#  'Turrones',
#  'Alimentación infantil',
#  'Biberón, chupete y menaje',
#  'Higiene y cuidado bebe',
#  'Toallitas y pañales',
#  'Cerveza',
#  'Cerveza sin alcohol',
#  'Licores',
#  'Sidra y cava',
#  'Tinto de verano y sangría',
#  'Vino blanco',
#  'Vino lambrusco y espumoso',
#  'Vino rosado',
#  'Vino tinto',
#  'Cacao soluble y chocolate a la taza',
#  'Café cápsula y monodosis',
#  'Café molido y en grano',
#  'Café soluble y otras bebidas',
#  'Té e infusiones',
#  'Arreglos carne',
#  'Aves y pollo',
#  'Carne congelada',
#  'Cerdo',
#  'Conejo y cordero',
#  'Embutido',
#  'Hamburguesas y picadas',
#  'Vacuno',
#  'Empanados y elaborados carne',
#  'Cereales',
#  'Galletas',
#  'Tortitas',
#  'Aves y jamón cocido',
#  'Bacón y salchichas',
#  'Chopped y mortadela',
#  'Embutido curado',
#  'Jamón serrano',
#  'Paté y sobrasada',
#  'Queso curado, semicurado y tierno',
#  'Queso lonchas, rallado y en porciones',
#  'Queso untable y fresco',
#  'Arroz y pasta congelado',
#  'Carne congelado',
#  'Helados',
#  'Hielo',
#  'Marisco congelado',
#  'Pescado congelado',
#  'Pizzas congeladas',
#  'Rebozados congelados',
#  'Tartas y churros congelados',
#  'Verdura congelados',
#  'Atún y otras conservas de pescado',
#  'Berberechos y mejillones',
#  'Conservas de verdura y frutas',
#  'Gazpacho y cremas',
#  'Sopa y caldo',
#  'Tomate conserva',
#  'Acondicionador y mascarilla',
#  'Champu',
#  'Coloración cabello',
#  'Fijación cabello',
#  'Peines y accesorios',
#  'Afeitado y cuidado para hombre',
#  'Afeitado y cuidado para hombre',
#  'Cuidado e higiene facial',
#  'Depilación',
#  'Desodorante',
#  'Gel y jabón de manos',
#  'Higiene bucal',
#  'Higiene íntima',
#  'Manicura y pedicura',
#  'Manicura y pedicura',
#  'Perfume y colonia',
#  'Protector solar y aftersun',
#  'Fitoterapia',
#  'Parafarmacia',
#  'Fruta',
#  'Lechuga y ensalada preparada',
#  'Verdura',
#  'Huevos',
#  'Leche y bebidas vegetales',
#  'Mantequilla y margarina',
#  'Detergente y suavizante ropa',
#  'Estropajo, bayeta y guantes',
#  'Insecticida y ambientador',
#  'Lejía y líquidos fuertes',
#  'Limpiacristales',
#  'Limpiahogar y friegasuelos',
#  'Limpieza baño y WC',
#  'Limpieza cocina',
#  'Limpieza muebles y multiusos',
#  'Limpieza vajilla',
#  'Menaje y conservación de alimentos',
#  'Papel higiénico y celulosa',
#  'Pilas y bolsas de basura',
#  'Utensilios de limpieza y calzado',
#  'Bases de maquillaje y corrector',
#  'Colorete y polvos',
#  'Labios',
#  'Ojos',
#  'Pinceles y brochas',
#  'Marisco',
#  'Pescado congelado',
#  'Pescado en bandeja',
#  'Pescado Fresco',
#  'Pescado Salazones y ahumados',
#  'sushi',
#  'Gato',
#  'Perro',
#  'Pez y otros',
#  'Bollería de horno',
#  'Bollería envasada',
#  'Harina y preparado repostería',
#  'Pan de horno',
#  'Pan de molde y otras especialidades',
#  'Pan tostado y rallado',
#  'Picos, rosquilletas y picatostes',
#  'Bollería de horno',
#  'Bollería envasada',
#  'Harina y preparado repostería',
#  'Pan de horno',
#  'Pan de molde y otras especialidades',
#  'Pan tostado y rallado',
#  'Picos, rosquilletas y picatostes',
#  'Tartas y pasteles',
#  'Velas y decoración',
#  'Pizzas',
#  'Platos preparados calientes',
#  'Platos preparados fríos',
#  'Bifidus',
#  'Flan y natillas',
#  'Gelatina y otros postres',
#  'Postres de soja',
#  'Yogures desnatados',
#  'Yogures griegos',
#  'Yogures líquidos',
#  'Yogures naturales y sabores',
#  'Yogures y postres infantiles',
#  'Zumo fruta variada',
#  'Melocotón y piña',
#  'Naranja',
#  'Tomate y otros sabores']

# %%
dia=pd.read_csv("dia_7dic.csv",encoding = "ISO-8859-1")
carrefour=pd.read_csv("carrefour_8dic.csv",encoding = "ISO-8859-1")
lidl=pd.read_csv("lidl.csv",encoding = "ISO-8859-1")
mercadona=pd.read_csv("mercadona.csv",encoding = "ISO-8859-1")

# %% [markdown]
# # dia

# %%
dia_oferta=dia

# %%
dia_oferta.isna().sum()
# Out:
# Unnamed: 0       0
# producto         0
# precio          57
# precio/kg       57
# none          7072
# dtype: int64

# %%
dia_oferta.dropna(how="any", inplace=True) #borro todas las filas que tengan todo nan

# %%
dia_oferta
# Out:
#       Unnamed: 0                                           producto  precio  \
# 11            11  DIA DULCE NOEL turrÃ³n de chocolate blanco cru...    0.99
# 24            24  DIA DULCE NOEL turrÃ³n de chocolate negro cruj...    0.99
# 367          367  DIA SELECCIÃN MUNDIAL queso provolone con orÃ...    1.61
# 373          373  \n\n\n\n\n\n\n\n\n\n\n\t\t\t\t\tNAVIDUL paleta...    4.79
# 479          479  NAVIDUL salchichÃ³n ibÃ©rico lonchas sobre 100...    1.99
# 480          480  NAVIDUL chorizo ibÃ©rico lonchas sobre 100 gr ...    1.99
# 866          866         MILKA chocolate con galleta tableta 300 gr    2.89
# 1115        1115           MILKA chocolate con leche tableta 270 gr    1.99
# 1274        1274  \n\n\n\n\n\n\n\n\n\n\n\t\t\t\t\tDANONE DANET n...    2.15
# 1275        1275  \n\n\n\n\n\n\n\n\n\n\n\t\t\t\t\tDANONE DANET n...    2.15
# 1331        1331  MILKA chocolate relleno de caramelo y avellana...    2.99
# 1704        1704          DANONE copa chocolate 2 unidades x 110 gr    1.45
# 1711        1711  DANONE OIKOS yogur griego natural pack 4 unida...    1.99
# 1712        1712  DANONE OIKOS yogur griego natural azucarado pa...    2.25
# 1801        1801               FERRERO rocher bombones caja 375 gr     8.99
# 1825        1825      DANONE flan de vainilla pack 4 unidades 100 g    1.65
# 1833        1833           FERRERO bombones collection caja 172 gr     6.99
# 1865        1865  \n\n\n\n\n\n\n\n\n\n\n\t\t\t\t\tMILKA chocolat...    3.09
# 1868        1868  OREO galletas baÃ±adas en chocolate blanco caj...    2.39
# 1873        1873                     RAFFAELLO bombones caja 150 gr    3.59
# 1878        1878  \n\n\n\n\n\n\n\n\n\n\n\t\t\t\t\tLA LECHERA lec...    1.44
# 2125        2125  DANONE OIKOS yogur griego con caramelo pack 2 ...    1.45
# 2163        2163     DANONE arroz con leche pack 2 unidades 130 gr     1.35
# 2164        2164  \n\n\n\n\n\n\n\n\n\n\n\t\t\t\t\tDANONE flan de...    2.39
# 2271        2271  \n\n\n\n\n\n\n\n\n\n\n\t\t\t\t\tMON CHERI bomb...    4.29
# 2355        2355  TWIX mini barritas rellenas de caramelo con ch...    1.59
# 2356        2356  SNICKERS Mini barritas rellenas de caramelo co...    1.59
# 2375        2375  MILKA chocolate relleno de caramelo y cacahuet...    3.09
# 2449        2449               MARS mini chocolatinas bolsa 130 gr     1.59
# 2534        2534  \n\n\n\n\n\n\n\n\n\n\n\t\t\t\t\tDANONE OIKOS y...    1.45
# 2748        2748  DANONE OIKOS yogur griego stracciatella pack 4...    2.45
# 3057        3057  MILKA chocolate con leche relleno de oreo tabl...    2.89
# 3266        3266  \n\n\n\n\n\n\n\n\n\n\n\t\t\t\t\tVOLL-DAMM cerv...    0.72
# 3541        3541  VOLL-DAMM cerveza doble malta pack 6 botellas ...    3.95
# 3747        3747  BERONIA vino tinto crianza DO Rioja botella 75...    7.02
# 3789        3789  BOMBAY Original ginebra london dry botella 70 ...   11.99
# 3811        3811  \n\n\n\n\n\n\n\n\n\n\n\t\t\t\t\tFEDERICO PATER...    4.39
# 3892        3892  MAYOR DE CASTILLA vino tinto botella 75 cl \n\...    2.13
# 3968        3968  BEEFEATER bebida espirituosa light 20Âº botell...   12.00
# 4050        4050  DIA MARI MARINERA almeja del PacÃ­fico envase ...    1.19
# 4221        4221  DIA MARI MARINERA palitos de surimi ultraconge...    1.49
# 4298        4298  ELVIVE crema suavizante color vive cabello teÃ...    2.39
# 4350        4350  ELVIVE mascarilla capilar total repair 5 tarro...    3.83
# 4880        4880  \n\n\n\n\n\n\n\n\n\n\n\t\t\t\t\tORIGINAL REMED...    3.19
# 4881        4881  \n\n\n\n\n\n\n\n\n\n\n\t\t\t\t\tORIGINAL REMED...    3.19
# 4971        4971  \n\n\n\n\n\n\n\n\n\n\n\t\t\t\t\tORIGINAL REMED...    2.15
# 4989        4989  ORIGINAL REMEDIES mascarilla dÃ©licatesse todo...    3.19
# 5015        5015  FRUCTIS mascarilla hidra rizos cabello rizo u ...    3.75
# 5016        5016  \n\n\n\n\n\n\n\n\n\n\n\t\t\t\t\tFRUCTIS mascar...    3.75
# 5565        5565  ORIGINAL REMEDIES acondicionador tesoros de mi...    2.95
#
#                          precio/kg                    none
# 11      \n\n7.45/Kg.\n4.95/Kg.\n\n    \t\t0.99 â¬\n\n\n\n
# 24      \n\n7.45/Kg.\n4.95/Kg.\n\n    \t\t0.99 â¬\n\n\n\n
# 367    \n\n10.75/Kg.\n8.05/Kg.\n\n         \t\t25%\n\n\n\n
# 373   \n\n58.56/Kg.\n46.06/Kg.\n\n    \t\t4.79 â¬\n\n\n\n
# 479   \n\n26.90/Kg.\n19.90/Kg.\n\n    \t\t1.99 â¬\n\n\n\n
# 480   \n\n23.90/Kg.\n19.90/Kg.\n\n    \t\t1.99 â¬\n\n\n\n
# 866                     9.63/Kg.\n  \t\t2Âª UD 50%\n\n\n\n
# 1115                    7.37/Kg.\n  \t\t2Âª UD 50%\n\n\n\n
# 1274                    4.48/Kg.\n  \t\t2Âª UD 50%\n\n\n\n
# 1275                    4.48/Kg.\n  \t\t2Âª UD 50%\n\n\n\n
# 1331                    9.97/Kg.\n  \t\t2Âª UD 50%\n\n\n\n
# 1704                    6.59/Kg.\n  \t\t2Âª UD 50%\n\n\n\n
# 1711                    4.52/Kg.\n  \t\t2Âª UD 50%\n\n\n\n
# 1712                    5.11/Kg.\n  \t\t2Âª UD 50%\n\n\n\n
# 1801                   23.97/Kg.\n  \t\t2Âª UD 50%\n\n\n\n
# 1825                    4.13/Kg.\n  \t\t2Âª UD 50%\n\n\n\n
# 1833                   41.61/Kg.\n  \t\t2Âª UD 50%\n\n\n\n
# 1865                   11.44/Kg.\n  \t\t2Âª UD 50%\n\n\n\n
# 1868                    9.72/Kg.\n  \t\t2Âª UD 50%\n\n\n\n
# 1873                   23.93/Kg.\n  \t\t2Âª UD 50%\n\n\n\n
# 1878    \n\n4.73/Kg.\n3.89/Kg.\n\n    \t\t1.44 â¬\n\n\n\n
# 2125                    6.59/Kg.\n  \t\t2Âª UD 50%\n\n\n\n
# 2163                    5.19/Kg.\n  \t\t2Âª UD 50%\n\n\n\n
# 2164                    5.98/Kg.\n  \t\t2Âª UD 50%\n\n\n\n
# 2271                   27.24/Kg.\n  \t\t2Âª UD 50%\n\n\n\n
# 2355                   12.23/Kg.\n  \t\t2Âª UD 50%\n\n\n\n
# 2356                   11.04/Kg.\n  \t\t2Âª UD 50%\n\n\n\n
# 2375                   11.20/Kg.\n  \t\t2Âª UD 50%\n\n\n\n
# 2449                   12.23/Kg.\n  \t\t2Âª UD 50%\n\n\n\n
# 2534                    6.59/Kg.\n  \t\t2Âª UD 50%\n\n\n\n
# 2748                    5.57/Kg.\n  \t\t2Âª UD 50%\n\n\n\n
# 3057                    9.63/Kg.\n  \t\t2Âª UD 50%\n\n\n\n
# 3266      \n\n2.42/l.\n2.18/l.\n\n        \t\t-10%\n\n\n\n
# 3541      \n\n2.93/l.\n2.63/l.\n\n        \t\t-10%\n\n\n\n
# 3747      \n\n9.85/l.\n9.36/l.\n\n         \t\t-5%\n\n\n\n
# 3789    \n\n18.56/l.\n17.13/l.\n\n   \t\t11.99 â¬\n\n\n\n
# 3811      \n\n7.80/l.\n5.85/l.\n\n        \t\t-25%\n\n\n\n
# 3892      \n\n4.07/l.\n2.84/l.\n\n        \t\t-30%\n\n\n\n
# 3968    \n\n20.13/l.\n17.14/l.\n\n      \t\tOferta\n\n\n\n
# 4050    \n\n3.98/Kg.\n2.64/Kg.\n\n    \t\t1.19 â¬\n\n\n\n
# 4221    \n\n3.98/Kg.\n3.31/Kg.\n\n    \t\t1.49 â¬\n\n\n\n
# 4298     \n\n11.96/l.\n9.56/l.\n\n        \t\t-20%\n\n\n\n
# 4350    \n\n15.97/l.\n12.77/l.\n\n        \t\t-20%\n\n\n\n
# 4880    \n\n13.30/l.\n10.63/l.\n\n        \t\t-20%\n\n\n\n
# 4881    \n\n13.30/l.\n10.63/l.\n\n        \t\t-20%\n\n\n\n
# 4971    \n\n13.45/l.\n10.75/l.\n\n        \t\t-20%\n\n\n\n
# 4989    \n\n13.30/l.\n10.63/l.\n\n        \t\t-20%\n\n\n\n
# 5015    \n\n15.63/l.\n12.50/l.\n\n        \t\t-20%\n\n\n\n
# 5016    \n\n15.63/l.\n12.50/l.\n\n        \t\t-20%\n\n\n\n
# 5565    \n\n14.76/l.\n11.80/l.\n\n        \t\t-20%\n\n\n\n

# %%
carrefour
# Out:
#       Unnamed: 0      precio       precio/kg  \
# 0              0  \n1,17 â¬     0,78 â¬/kg
# 1              1  \n3,95 â¬      3,95 â¬/l
# 2              2  \n0,22 â¬     0,22 â¬/kg
# 3              3  \n1,05 â¬     1,31 â¬/kg
# 4              4  \n1,80 â¬     0,90 â¬/kg
# ...          ...         ...             ...
# 2259        2259  \n0,99 â¬     0,10 â¬/ud
# 2260        2260  \n1,06 â¬     0,11 â¬/ud
# 2261        2261  \n3,29 â¬  2,19 â¬/100ml
# 2262        2262  \n0,61 â¬  0,24 â¬/100ml
# 2263        2263  \n0,80 â¬     0,03 â¬/ud
#
#                                                producto     anadir  \
# 0                      AzÃºcar blanco Azucarera 1,5 kg.  AÃ±adir\n
# 1           Aceite de oliva virgen extra Carrefour 1 l.  AÃ±adir\n
# 2                       Sal marina fina Carrefour 1 kg.  AÃ±adir\n
# 3     Galletas MarÃ­a dorada Carrefour sin aceite de...  AÃ±adir\n
# 4     Yogur de fresa, de macedonia, de limÃ³n y de f...  AÃ±adir\n
# ...                                                 ...        ...
# 2259  Mascarillas quirÃºrgicas IIR desechables para ...  AÃ±adir\n
# 2260  Mascarilla quirÃºrgica desechable tipo IIR inf...  AÃ±adir\n
# 2261                Suero fisiolÃ³gico Carrefour 30 ud.  AÃ±adir\n
# 2262     Agua oxigenada 10 volÃºmenes Carrefour 250 ml.  AÃ±adir\n
# 2263  Tiras adhesivas elÃ¡sticas transpirables Carre...  AÃ±adir\n
#
#                                                    none link    m    k    s
# 0     https://www.carrefour.es/supermercado/la-despe...  NaN  NaN  NaN  NaN
# 1     https://www.carrefour.es/supermercado/la-despe...  NaN  NaN  NaN  NaN
# 2     https://www.carrefour.es/supermercado/la-despe...  NaN  NaN  NaN  NaN
# 3     https://www.carrefour.es/supermercado/la-despe...  NaN  NaN  NaN  NaN
# 4     https://www.carrefour.es/supermercado/la-despe...  NaN  NaN  NaN  NaN
# ...                                                 ...  ...  ...  ...  ...
# 2259  https://www.carrefour.es/supermercado/parafarm...  NaN  NaN  NaN  NaN
# 2260  https://www.carrefour.es/supermercado/parafarm...  NaN  NaN  NaN  NaN
# 2261  https://www.carrefour.es/supermercado/parafarm...  NaN  NaN  NaN  NaN
# 2262  https://www.carrefour.es/supermercado/parafarm...  NaN  NaN  NaN  NaN
# 2263  https://www.carrefour.es/supermercado/parafarm...  NaN  NaN  NaN  NaN
#
# [2264 rows x 10 columns]

# %%
li data-submenu-href alcampo 
ul class pagination 
a href
