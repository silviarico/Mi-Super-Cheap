# %%
import pandas as pd
import numpy as np
import re
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
import time
from selenium.webdriver.support.ui import Select
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.support.ui import Select
import math

# %%
s=Service("/mnt/c/Users/silvi/Desktop/ironhack/proyectos/proyecto2/pipeline_proyecto1-2/jupyter/chromedriver.exe")
driver = webdriver.Chrome(service=s)
opciones=Options()

opciones.add_experimental_option('excludeSwitches', ['enable-automation'])
opciones.add_experimental_option('useAutomationExtension', False)

opciones.headless=False    # si True, no aperece la ventana (headless=no visible)

opciones.add_argument('--start-maximized')         # comienza maximizado

opciones.add_argument('user-data-dir=selenium')    # mantiene las cookies

#opciones.add_extension('driver_folder/adblock.crx')       # adblocker

opciones.add_argument('--incognito')              # incognito

# %%
url = ('https://www.carrefour.es/supermercado/')
driver.get(url)
time.sleep(5)

driver.find_element_by_css_selector('#onetrust-accept-btn-handler').click()
# Out:
# <ipython-input-4-240fb0e18c45>:5: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_css_selector('#onetrust-accept-btn-handler').click()

# %%
body = driver.execute_script("return document.body")
source = body.get_attribute('innerHTML') 
soup_sc = BeautifulSoup(source, "html.parser")

# %% [markdown]
# https://www.carrefour.es/supermercado/el-mercado/cat20002/c?ic_source=portal-y-corporativo&ic_medium=category-food-box&ic_content=ns&offset=24

# %% [markdown]
# https://www.carrefour.es/supermercado/el-mercado/cat20002/c?ic_source=portal-y-corporativo&ic_medium=category-food-box&ic_content=ns

# %%
paginas=soup_sc.findAll("a",{"class": "nav-first-level-categories__list-element ripple"})

# %%
lista_enlaces=[f"https://www.carrefour.es{elemento.get('href')}" for elemento in paginas]

# %%
lista_enlaces.remove('https://www.carrefour.es/supermercado/editOnlineList')

# %%
lista_enlaces
# Out:
# ['https://www.carrefour.es/supermercado/la-despensa/cat20001/c',
#  'https://www.carrefour.es/supermercado/productos-frescos/cat20002/c',
#  'https://www.carrefour.es/supermercado/bebidas/cat20003/c',
#  'https://www.carrefour.es/supermercado/perfumeria-e-higiene/cat20004/c',
#  'https://www.carrefour.es/supermercado/limpieza-y-hogar/cat20005/c',
#  'https://www.carrefour.es/supermercado/bebe/cat20006/c',
#  'https://www.carrefour.es/supermercado/mascotas/cat20007/c',
#  'https://www.carrefour.es/supermercado/parafarmacia/cat20008/c']

# %%
url = 'https://www.carrefour.es/supermercado/la-despensa/cat20001/c'
driver.get(url)
driver.implicitly_wait(2)
body = driver.execute_script("return document.body")
source = body.get_attribute('innerHTML') 
soup_sc = BeautifulSoup(source, "html.parser")
N=soup_sc.findAll("span",{"class": "pagination__results-item"})
text=[p.getText() for p in N][2]
num = math.floor(int(text)/24)

# %%
"""lista_links=[]
x=24
for i in range(num-1):
    lista_links.append(f"https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset={x}")
    x+=24
lista_links"""
# Out:
# 'lista_links=[]\nx=24\nfor i in range(num-1):\n    lista_links.append(f"https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset={x}")\n    x+=24\nlista_links'

# %%
lista_all=[]
for i in lista_enlaces:
    url = i
    driver.get(url)
    driver.implicitly_wait(2)
    body = driver.execute_script("return document.body")
    source = body.get_attribute('innerHTML') 
    soup_sc = BeautifulSoup(source, "html.parser")
    N=soup_sc.findAll("span",{"class": "pagination__results-item"})
    text=[p.getText() for p in N][2]
    num = math.floor(int(text)/24)
    x=24
    for z in range(num-1):
        lista_all.append(f"{i}?offset={x}")
        x+=24

# %%
lista_all=lista_all+lista_enlaces

# %%
dic_parseado={}
lista_productos=[]
for i in lista_all:
    url = i
    driver.get(url)
    time.sleep(1)
    iter=1
    while True:
    
        scrollHeight = driver.execute_script("return document.documentElement.scrollHeight")
        Height=250*iter
        driver.execute_script("window.scrollTo(0, " + str(Height) + ");")
        if Height > scrollHeight:
            #print('End of page')
            break
        time.sleep(0.5)
        iter+=1
    body = driver.execute_script("return document.body")
    source = body.get_attribute('innerHTML') 
    soup_sc = BeautifulSoup(source, "html.parser")
    dic_parseado[f"{i}"]=soup_sc
    productos=soup_sc.findAll("div",{"class": "product-card__detail"})
    text=[p.getText() for p in productos]
    for x in text:
        c=x.replace("              ","")
        c=x.replace("            ","")
        c=x.replace("          ","")
        c=x.replace("        ","")
        c=x.replace("      ","")
        c=x.replace("    ","")
        c=x.replace("  ","")
        lista=c.split("\n\n")
        lista.append(i)
        lista_productos.append(lista)
# Out:
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page
# End of page

# %%
largo=[]
for i in lista_productos:
    largo.append(len(i))
x=set(largo)
x
# Out:
# {5, 6, 7, 8, 9}

# %%
len(lista_productos)
# Out:
# 7574

# %%
import pickle

with open('parrot.pkl', 'wb') as f:
    pickle.dump(lista_productos, f)
"""with open('parrot.pkl', 'rb') as f:
    mynewlist = pickle.load(f)"""
# Out:
# "with open('parrot.pkl', 'rb') as f:\n    mynewlist = pickle.load(f)"

# %%
lista_productos[7000]
# Out:
# ['\n19,39 €',
#  '2,59 €/100ml',
#  'Fluido hidratante Lipikar La Roche-Posay 750 ml.',
#  'Añadir\n',
#  'https://www.carrefour.es/supermercado/parafarmacia/cat20008/c?offset=384']

# %% [markdown]
# ## Limpieza

# %%
lista_borrar=['Entero limpio',
  'Rodajas',
  'Filetes',
  'Espalda con espina',
  'Añadir\n','Sin lactosa','Sin gluten',
  'Ver productos de la promoción',
  'Agotado temporalmente\n','Bio','Rebanada gruesa',
  'Rebanada mediana','Rebanada fina',
  'Pieza','Cuña de 1/8',
  'Medio queso',
  'Queso entero','Congelado','Loncha gruesa 3/4mm',
  'Loncha normal 2/3mm','Sin lactosa\nTipo de corte:\nLoncha fina 1mm','Filete normal 1 cm',
  '- Sin entrega: lunes','\nVer productos de la promoción','Varias promociones.\n Ver todas \nAñadir\n','Tipo de corte:\nEntero limpio',
   'Limpio sin cabeza']

# %%
lista_prueba=lista_productos

for i in lista_borrar:
    for x in lista_prueba:
        if i in x:
            x.remove(i)

# %%
largo2=[]
for i in lista_prueba:
    largo2.append(len(i))
x2=set(largo2)
x2
# Out:
# {4, 5}

# %%
carr_4=[]
carr_5=[]

for i in lista_prueba:
    if len(i)==4:
        carr_4.append(i)
    elif len(i)==5:
        carr_5.append(i)

# %% [markdown]
# ## Sin Oferta

# %%
carr_sin=pd.DataFrame(carr_4, columns=["precio","precio_rel","producto","link"])

# %%
carr_sin["Q"]=carr_sin["producto"].str.extract(r"( \d+ .+)",)

# %%
carr_sin.head()
# Out:
#      precio precio_rel                                           producto  \
# 0  \n3,35 €   1,67 €/l  Caldo casero de pollo Gallina Blanca sin glute...
# 1  \n3,95 €   3,95 €/l        Aceite de oliva virgen extra Carrefour 1 l.
# 2  \n0,22 €  0,22 €/kg                    Sal marina fina Carrefour 1 kg.
# 3  \n1,80 €  0,90 €/kg  Yogur de fresa, de macedonia, de limón y de fr...
# 4  \n3,20 €   3,20 €/l          Aceite de oliva suave 0,4º Carrefour 1 l.
#
#                                                 link                       Q
# 0  https://www.carrefour.es/supermercado/la-despe...         2 briks de 1 l.
# 1  https://www.carrefour.es/supermercado/la-despe...                    1 l.
# 2  https://www.carrefour.es/supermercado/la-despe...                   1 kg.
# 3  https://www.carrefour.es/supermercado/la-despe...   16 unidades de 125 g.
# 4  https://www.carrefour.es/supermercado/la-despe...                    1 l.

# %%
carr_sin = carr_sin.replace(to_replace ='[\n]', value = '', regex = True)
carr_sin = carr_sin.replace(to_replace ='[€]', value = '', regex = True)
carr_sin = carr_sin.replace(to_replace ='[,]', value = '.', regex = True)
carr_sin = carr_sin.replace(to_replace ='[ó]', value = 'o', regex = True) 
carr_sin = carr_sin.replace(to_replace ='[á]', value = 'a', regex = True)
carr_sin = carr_sin.replace(to_replace ='[é]', value = 'e', regex = True)
carr_sin = carr_sin.replace(to_replace ='[ó]', value = 'o', regex = True) 
carr_sin = carr_sin.replace(to_replace ='[í]', value = 'i', regex = True)
carr_sin = carr_sin.replace(to_replace ='[ú]', value = 'u', regex = True) 
carr_sin = carr_sin.replace(to_replace ='[ñ]', value = 'n', regex = True)

# %%
carr_sin.tail()
# Out:
#      precio   precio_rel                                           producto  \
# 6533  8.29   5.53 /100ml  Dentifrico menta fresca Repair & Protect Senso...
# 6534  0.99      4.21 /kg  Tarrito de menestra de cordero desde 6 meses N...
# 6535  9.39   6.26 /100ml  Dentifrico para el cuidado de las encias herba...
# 6536  7.65   1.53 /100ml  Colutorio diario para el cuidado de encias Par...
# 6537  0.99      4.21 /kg  Tarrito de pollo con guisantes y zanahorias de...
#
#                                                    link  \
# 6533  https://www.carrefour.es/supermercado/parafarm...
# 6534  https://www.carrefour.es/supermercado/parafarm...
# 6535  https://www.carrefour.es/supermercado/parafarm...
# 6536  https://www.carrefour.es/supermercado/parafarm...
# 6537  https://www.carrefour.es/supermercado/parafarm...
#
#                              Q
# 6533      2 unidades de 75 ml.
# 6534   6 meses Nutriben 235 g.
# 6535      2 unidades de 75 ml.
# 6536                   500 ml.
# 6537   6 meses Nutriben 235 g.

# %%
carr_sin[["precio_medida","medida"]]=carr_sin["precio_rel"].str.split("/",expand=True)

# %%
def limpiar(a):
    if len(a)>5:
        return 1
    else:
        return a

# %%
carr_sin.precio=pd.to_numeric(carr_sin.precio.str.replace(" ",""))

# %%
carr_sin.precio_medida=pd.to_numeric(carr_sin.precio_medida.str.replace(" ","").apply(limpiar))

# %%
carr_sin["Q_medida"]=round(carr_sin["precio"]/carr_sin["precio_medida"],3)

# %%
carr_sin.head()
# Out:
#    precio precio_rel                                           producto  \
# 0    3.35    1.67 /l  Caldo casero de pollo Gallina Blanca sin glute...
# 1    3.95    3.95 /l        Aceite de oliva virgen extra Carrefour 1 l.
# 2    0.22   0.22 /kg                    Sal marina fina Carrefour 1 kg.
# 3    1.80   0.90 /kg  Yogur de fresa. de macedonia. de limon y de fr...
# 4    3.20    3.20 /l          Aceite de oliva suave 0.4º Carrefour 1 l.
#
#                                                 link                       Q  \
# 0  https://www.carrefour.es/supermercado/la-despe...         2 briks de 1 l.
# 1  https://www.carrefour.es/supermercado/la-despe...                    1 l.
# 2  https://www.carrefour.es/supermercado/la-despe...                   1 kg.
# 3  https://www.carrefour.es/supermercado/la-despe...   16 unidades de 125 g.
# 4  https://www.carrefour.es/supermercado/la-despe...                    1 l.
#
#    precio_medida medida  Q_medida
# 0           1.67      l     2.006
# 1           3.95      l     1.000
# 2           0.22     kg     1.000
# 3           0.90     kg     2.000
# 4           3.20      l     1.000

# %%
carr_sin.to_csv("carrefour/carr_sinDEF.csv")

# %% [markdown]
# ## Con Oferta

# %%
carr_con=pd.DataFrame(carr_5, columns=["precio_anterior","precio","precio_rel","producto","link"])

# %%
carr_con = carr_con.replace(to_replace ='[\n]', value = '', regex = True)
carr_con = carr_con.replace(to_replace ='[€]', value = '', regex = True)
carr_con = carr_con.replace(to_replace ='[,]', value = '.', regex = True)
carr_con = carr_con.replace(to_replace ='[ó]', value = 'o', regex = True) 
carr_con = carr_con.replace(to_replace ='[á]', value = 'a', regex = True)
carr_con = carr_con.replace(to_replace ='[é]', value = 'e', regex = True)
carr_con = carr_con.replace(to_replace ='[ó]', value = 'o', regex = True) 
carr_con = carr_con.replace(to_replace ='[í]', value = 'i', regex = True)
carr_con = carr_con.replace(to_replace ='[ú]', value = 'u', regex = True) 
carr_con = carr_con.replace(to_replace ='[ñ]', value = 'n', regex = True)

# %%
carr_con.head()
# Out:
#   precio_anterior precio           precio_rel  \
# 0           0.82   0.79     0.82 /l | 0.79 /l
# 1           0.82   0.79     0.82 /l | 0.79 /l
# 2           2.05   1.93   2.23 /kg | 2.10 /kg
# 3           0.82   0.79     0.82 /l | 0.79 /l
# 4           2.35   2.12   5.34 /kg | 4.82 /kg
#
#                                             producto  \
# 0  Leche semidesnatada Central Lechera Asturiana ...
# 1   Leche entera Central Lechera Asturiana brik 1 l.
# 2  Tomate frito Solis sin gluten y sin lactosa pa...
# 3  Leche desnatada Central Lechera Asturiana brik...
# 4  Yogur griego con stracciatella Danone Oikos si...
#
#                                                 link precio_rel_anterior  \
# 0  https://www.carrefour.es/supermercado/la-despe...            0.82 /l
# 1  https://www.carrefour.es/supermercado/la-despe...            0.82 /l
# 2  https://www.carrefour.es/supermercado/la-despe...           2.23 /kg
# 3  https://www.carrefour.es/supermercado/la-despe...            0.82 /l
# 4  https://www.carrefour.es/supermercado/la-despe...           5.34 /kg
#
#   precio_rel_1 precio_medida medida
# 0      0.79 /l         0.79       l
# 1      0.79 /l         0.79       l
# 2     2.10 /kg         2.10      kg
# 3      0.79 /l         0.79       l
# 4     4.82 /kg         4.82      kg

# %%
carr_con[["precio_rel_anterior","precio_rel_1"]]=carr_con["precio_rel"].str.split("|",expand=True)

# %%
carr_con.precio.unique()
# Out:
# array(['0.79 ', '1.93 ', '2.12 ', '6.19 ', '3.19 ', '3.25 ', '1.43 ',
#        '1.53 ', '1.15 ', '1.60 ', '2.70 ', '2.85 ', '2.09 ', '1.79 ',
#        '2.50 ', '3.15 ', '3.75 ', '2.65 ', '1.14 ', '2.55 ', '1.80 ',
#        '2.15 ', '1.87 ', '1.90 ', '2.69 ', '3.79 ', '4.65 ', '3.95 ',
#        '4.29 ', '2.75 ', '2.29 ', '1.63 ', '0.69 ', '2.49 ', '1.99 ',
#        '12.99 ', '1.74 ', '2.39 ', '2.45 ', '1.48 ', '3.10 ', '3.49 ',
#        '2.95 ', '1.98 ', '7.95 /kg', '4.11 ', '1.58 ', '1.65 ',
#        '15.40 /kg', '8.99 ', '1.78 ', '4.79 ', '1.35 ', '2.19 ', '5.87 ',
#        '1.49 ', '1.68 ', '4.50 ', '3.90 ', '1.85 ', '2.59 ', '4.24 ',
#        '5.03 ', '29.90 /kg', '4.59 ', '3.99 ', '8.15 ', '4.47 ', '11.89 ',
#        '13.99 ', '3.20 ', '105 ', '3.59 ', '4.22 ', '1.56 ', '1.19 ',
#        '49 ', '8.99 /kg', '5.95 ', '1 ', '0.84 ', '8.29 ', '11.49 ',
#        '11.95 ', '6.24 ', '0.53 ', '3.70 ', '5.35 ', '3.85 ', '29.90 ',
#        '7.40 ', '7.29 ', '7.99 ', '0.80 ', '1.54 ', '23.49 ', '1.55 ',
#        '13.09 ', '6.39 ', '0.85 ', '6.99 ', '14.30 ', '2.39 /l', '8.49 ',
#        '59 ', '7.70 ', '18.49 ', '6.85 ', '20.90 ', '7.95 ', '18.17 ',
#        '2.47 ', '4.25 ', '1.89 ', '4.75 ', '4.09 ', '1.70 ', '2.99 ',
#        '3.39 ', '2.79 ', '2.05 ', '2.10 ', '3.29 ', '8.59 ', '5.10 ',
#        '2.89 ', '4.35 ', '2.20 ', '3.60 ', '4.45 ', '3.35 ', '6.69 ',
#        '7.06 ', '4.99 ', '5.45 ', '4.95 ', '9.69 ', '1.26 /100ml',
#        '5.19 ', '26.50 ', '26.30 ', '4.10 ', '30.45 ', '18.69 ', '24.40 ',
#        '9.79 ', '34.99 ', '3.30 ', '7.80 ', '3.55 ', '11.69 ', '9.29 ',
#        '4.80 ', '2.36 ', '6.49 ', '3.69 ', '16.19 ', '8.65 ', '19.48 ',
#        '10.99 ', '4.49 ', '5.75 ', '3.57 ', '3.83 ', '12.85 ', '7.09 ',
#        '13.39 ', '13.49 ', '9.19 ', '16.39 ', '9.59 ', '9.95 ', '10.95 ',
#        '17.65 ', '3.89 ', '23.98 ', '9.35 ', '14.89 ', '12.24 ', '9.85 ',
#        '6.59 ', '5.15 ', '4.85 ', '9.89 ', '5.50 ', '32.40 ', '24.20 ',
#        '23.70 ', '17.84 ', '16.99 ', '2.60 ', '6.80 ', '27.25 ', '19.99 '],
#       dtype=object)

# %%
carr_con[["precio_medida","medida"]]=carr_con["precio_rel_1"].str.split("/",expand=True)

# %%
carr_con.precio=carr_con.precio.str.replace(" ","")
carr_con.precio=carr_con.precio.str.replace("/kg","")
carr_con.precio=carr_con.precio.str.replace("/100ml","")
carr_con.precio=pd.to_numeric(carr_con.precio, errors="coerce")

# %%
carr_con.precio_medida=pd.to_numeric(carr_con.precio_medida.str.replace(" ",""))

# %%
carr_con["Q_medida"]=round(carr_con["precio"]/carr_con["precio_medida"],3)
carr_con.head()
# Out:
#   precio_anterior  precio           precio_rel  \
# 0           0.82     0.79    0.82 /l | 0.79 /l
# 1           0.82     0.79    0.82 /l | 0.79 /l
# 2           2.05     1.93  2.23 /kg | 2.10 /kg
# 3           0.82     0.79    0.82 /l | 0.79 /l
# 4           2.35     2.12  5.34 /kg | 4.82 /kg
#
#                                             producto  \
# 0  Leche semidesnatada Central Lechera Asturiana ...
# 1   Leche entera Central Lechera Asturiana brik 1 l.
# 2  Tomate frito Solis sin gluten y sin lactosa pa...
# 3  Leche desnatada Central Lechera Asturiana brik...
# 4  Yogur griego con stracciatella Danone Oikos si...
#
#                                                 link precio_rel_anterior  \
# 0  https://www.carrefour.es/supermercado/la-despe...            0.82 /l
# 1  https://www.carrefour.es/supermercado/la-despe...            0.82 /l
# 2  https://www.carrefour.es/supermercado/la-despe...           2.23 /kg
# 3  https://www.carrefour.es/supermercado/la-despe...            0.82 /l
# 4  https://www.carrefour.es/supermercado/la-despe...           5.34 /kg
#
#   precio_rel_1  precio_medida medida  Q_medida
# 0      0.79 /l           0.79      l     1.000
# 1      0.79 /l           0.79      l     1.000
# 2     2.10 /kg           2.10     kg     0.919
# 3      0.79 /l           0.79      l     1.000
# 4     4.82 /kg           4.82     kg     0.440

# %%
carr_con.to_csv("carrefour/carr_conDEF.csv")
