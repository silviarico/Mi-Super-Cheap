# %%
import pandas as pd
import numpy as np
import re
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
import time
from selenium.webdriver.support.ui import Select
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.support.ui import Select
import math

# %%
s=Service("/mnt/c/Users/silvi/Desktop/ironhack/proyectos/proyecto2/pipeline_proyecto1-2/jupyter/chromedriver.exe")
driver = webdriver.Chrome(service=s)
opciones=Options()

opciones.add_experimental_option('excludeSwitches', ['enable-automation'])
opciones.add_experimental_option('useAutomationExtension', False)

opciones.headless=False    # si True, no aperece la ventana (headless=no visible)

opciones.add_argument('--start-maximized')         # comienza maximizado

opciones.add_argument('user-data-dir=selenium')    # mantiene las cookies

#opciones.add_extension('driver_folder/adblock.crx')       # adblocker

opciones.add_argument('--incognito')              # incognito

# %%
url = ('https://www.carrefour.es/supermercado/')
driver.get(url)
time.sleep(5)

driver.find_element_by_css_selector('#onetrust-accept-btn-handler').click()
# Out:
# <ipython-input-96-240fb0e18c45>:5: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_css_selector('#onetrust-accept-btn-handler').click()

# %%
body = driver.execute_script("return document.body")
source = body.get_attribute('innerHTML') 
soup_sc = BeautifulSoup(source, "html.parser")

# %% [markdown]
# https://www.carrefour.es/supermercado/el-mercado/cat20002/c?ic_source=portal-y-corporativo&ic_medium=category-food-box&ic_content=ns&offset=24

# %% [markdown]
# https://www.carrefour.es/supermercado/el-mercado/cat20002/c?ic_source=portal-y-corporativo&ic_medium=category-food-box&ic_content=ns

# %%
paginas=soup_sc.findAll("a",{"class": "nav-first-level-categories__list-element ripple"})

# %%
lista_enlaces=[f"https://www.carrefour.es{elemento.get('href')}" for elemento in paginas]

# %%
lista_enlaces.remove('https://www.carrefour.es/supermercado/editOnlineList')

# %%
lista_enlaces
# Out:
# ['https://www.carrefour.es/supermercado/la-despensa/cat20001/c',
#  'https://www.carrefour.es/supermercado/productos-frescos/cat20002/c',
#  'https://www.carrefour.es/supermercado/bebidas/cat20003/c',
#  'https://www.carrefour.es/supermercado/perfumeria-e-higiene/cat20004/c',
#  'https://www.carrefour.es/supermercado/limpieza-y-hogar/cat20005/c',
#  'https://www.carrefour.es/supermercado/bebe/cat20006/c',
#  'https://www.carrefour.es/supermercado/mascotas/cat20007/c',
#  'https://www.carrefour.es/supermercado/parafarmacia/cat20008/c']

# %%
url = 'https://www.carrefour.es/supermercado/la-despensa/cat20001/c'
driver.get(url)
driver.implicitly_wait(2)
body = driver.execute_script("return document.body")
source = body.get_attribute('innerHTML') 
soup_sc = BeautifulSoup(source, "html.parser")
N=soup_sc.findAll("span",{"class": "pagination__results-item"})
text=[p.getText() for p in N][2]
num = math.floor(int(text)/24)

# %%
lista_links=[]
x=24
for i in range(num-1):
    lista_links.append(f"https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset={x}")
    x+=24
lista_links
# Out:
# ['https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=24',
#  'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=48',
#  'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=72',
#  'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=96',
#  'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=120',
#  'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=144',
#  'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=168',
#  'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=192',
#  'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=216',
#  'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=240',
#  'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=264',
#  'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=288',
#  'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=312',
#  'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=336',
#  'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=360',
#  'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=384',
#  'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=408',
#  'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=432',
#  'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=456',
#  'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=480',
#  'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=504',
#  'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=528',
#  'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=552',
#  'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=576',
#  'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=600',
#  'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=624',
#  'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=648',
#  'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=672',
#  'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=696',
#  'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=720',
#  'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=744',
#  'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=768',
#  'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=792',
#  'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=816',
#  'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=840',
#  'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=864',
#  'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=888',
#  'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=912',
#  'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=936',
#  'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=960',
#  'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=984']

# %%
lista_all=[]
for i in lista_enlaces:
    url = i
    driver.get(url)
    driver.implicitly_wait(2)
    body = driver.execute_script("return document.body")
    source = body.get_attribute('innerHTML') 
    soup_sc = BeautifulSoup(source, "html.parser")
    N=soup_sc.findAll("span",{"class": "pagination__results-item"})
    text=[p.getText() for p in N][2]
    num = math.floor(int(text)/24)
    x=24
    for z in range(num-1):
        lista_all.append(f"{i}?offset={x}")
        x+=24

# %%
lista_all=lista_all+lista_enlaces
# Out:
# 283

# %%
lista_productos=[]
for i in lista_all:
    url = i
    driver.get(url)
    driver.implicitly_wait(2)
    body = driver.execute_script("return document.body")
    source = body.get_attribute('innerHTML') 
    soup_sc = BeautifulSoup(source, "html.parser")
    productos=soup_sc.findAll("div",{"class": "product-card__detail"})
    text=[p.getText() for p in productos]
    for x in text:
        c=x.replace("              ","")
        c=x.replace("            ","")
        c=x.replace("          ","")
        c=x.replace("        ","")
        c=x.replace("      ","")
        c=x.replace("    ","")
        c=x.replace("  ","")
        lista=c.split("\n\n")
        lista.append(i)
        lista_productos.append(lista)

# %%
productos=soup_sc.findAll("div",{"class": "product-card__detail"})

# %%
lista_productos
# Out:
# [['\n1,17 €',
#   '0,78 €/kg',
#   'Azúcar blanco Azucarera 1,5 kg.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=24'],
#  ['\n3,95 €',
#   '3,95 €/l',
#   'Aceite de oliva virgen extra Carrefour 1 l.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=24'],
#  ['\n0,22 €',
#   '0,22 €/kg',
#   'Sal marina fina Carrefour 1 kg.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=24'],
#  ['\n1,05 €',
#   '1,31 €/kg',
#   'Galletas María dorada Carrefour sin aceite de palma 800 g.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=24'],
#  ['\n1,80 €',
#   '0,90 €/kg',
#   'Yogur de fresa, de macedonia, de limón y de fresa-plátano Carrefour pack de 16 unidades de 125 g.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=24'],
#  ['\n1,99 €',
#   '3,98 €/docena',
#   'Huevos M-L ecológicos Carrefour Bio 6 ud.',
#   'Bio',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=24'],
#  ['\n0,86 €',
#   '0,86 €/kg',
#   'Arroz largo categoría primera Carrefour 1 kg.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=24'],
#  ['\n3,20 €',
#   '3,20 €/l',
#   'Aceite de oliva suave 0,4º Carrefour 1 l.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=24'],
#  ['\n1,30 €',
#   '1,30 €/kg',
#   'Fideo cabellín Carrefour 1 kg.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=48'],
#  ['\n2,05 €',
#   '1,95 €/kg',
#   'Tomate frito Orlando sin gluten pack de 3 briks de 350 g.',
#   'Sin gluten',
#   'Ver productos de la promoción',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=48'],
#  ['\n15,50 €',
#   '3,10 €/l',
#   'Aceite de oliva suave 0,4º Carrefour garrafón 5 l.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=48'],
#  ['\n0,94 €',
#   '0,94 €/l',
#   'Leche entera Pascual brik 1 l.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=48'],
#  ['\n0,70 €',
#   '1,40 €/kg',
#   'Copos de avena Carrefour 500 g.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=48'],
#  ['\n2,99 €',
#   '3,48 €/kg',
#   'Galletas con cereales, vitaminas y calcio Tosta Rica Cuétara 860 g.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=48'],
#  ['\n1,49 €',
#   '1,99 €/kg',
#   'Yogur griego con stracciatella Carrefour Extra sin gluten pack de 6 unidades de 125 g.',
#   'Sin gluten',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=48'],
#  ['\n0,22 €',
#   '0,22 €/kg',
#   'Sal marina yodada fina Carrefour 1 kg.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=48'],
#  ['\n0,82 €',
#   '0,79 €',
#   '0,82 €/l\n | \n0,79 €/l',
#   'Leche desnatada Central Lechera Asturiana brik 1 l.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=72'],
#  ['\n2,59 €',
#   '12,95 €/kg',
#   'Nueces sin cáscara Carrefour 200 g.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=72'],
#  ['\n18,30 €',
#   '3,66 €/l',
#   'Aceite de oliva virgen extra Carrefour garrafa 5 l.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=72'],
#  ['\n2,67 €',
#   '4,11 €/l',
#   "Mayonesa Hellmann's sin gluten tarro 650 ml.",
#   'Sin gluten',
#   'Ver productos de la promoción',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=72'],
#  ['\n1,25 €',
#   '0,83 €/l',
#   'Leche semidesnatada Central Lechera Asturiana botella 1,5 l.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=72'],
#  ['\n2,35 €',
#   '2,12 €',
#   '5,34 €/kg\n | \n4,82 €/kg',
#   'Yogur griego con stracciatella Danone Oikos sin gluten pack de 4 unidades de 110 g.',
#   'Sin gluten',
#   'Ver productos de la promoción',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=72'],
#  ['\n6,99 €',
#   '6,55 €',
#   '22,40 €/kg\n | \n20,99 €/kg',
#   'Atún claro en aceite de oliva Calvo sin lactosa pack de 6 latas de 52 g.',
#   'Sin lactosa',
#   'Ver productos de la promoción',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=72'],
#  ['\n0,99 €',
#   '0,99 €/kg',
#   'Harina de trigo Gallo 1 kg.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=72'],
#  ['\n2,19 €',
#   '4,98 €/kg',
#   'Yogur griego natural Danone Oikos sin gluten pack de 4 unidades de 110 g.',
#   'Sin gluten',
#   'Ver productos de la promoción',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=96'],
#  ['\n1,89 €',
#   '5,48 €/kg',
#   'Champiñones laminados Carrefour pack de 3 unidades de 115 g.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=96'],
#  ['\n0,94 €',
#   '0,94 €/l',
#   'Leche desnatada 0% MG Pascual brik 1 l.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=96'],
#  ['\n1,05 €',
#   '1,40 €/kg',
#   'Yogur griego natural azucarado Carrefour Extra pack de 6 unidades de 125 g.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=96'],
#  ['\n3,24 €',
#   '3,19 €',
#   '9,26 €/kg\n | \n9,11 €/kg',
#   'Pizza de jamón y queso fina y crujiente Forno Di Pietra Buitoni 350 g.',
#   'Congelado',
#   'Ver productos de la promoción',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=96'],
#  ['\n2,14 €',
#   '2,14 €/kg',
#   'Yogur natural Danone pack de 8 unidades de 120 g.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=96'],
#  ['\n1,16 €',
#   '4,64 €/kg',
#   'Arroz basmati para microondas Brillante pack de 2 ud. de 125 g.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=96'],
#  ['\n5,05 €',
#   '12,62 €/kg',
#   'Nueces peladas carrefour 400 g.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=96'],
#  ['\n3,35 €',
#   '1,67 €/l',
#   'Caldo casero de cocido Gallina Blanca pack de 2 briks de 1 l.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=120'],
#  ['\n1,30 €',
#   '1,73 €/kg',
#   'Yogur griego de fresa Carrefour Extra sin gluten pack de 6 unidades de 125 g.',
#   'Sin gluten',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=120'],
#  ['\n1,29 €',
#   '17,20 €/kg',
#   'Pandilla sabor queso Cheetos 75 g.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=120'],
#  ['\n0,94 €',
#   '6,27 €/kg',
#   'Galletas con tableta de chocolate y leche Carrefour 150 g.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=120'],
#  ['\n1,19 €',
#   '3,97 €/kg',
#   'Petit de fresa Danonino sin gluten pack de 6 unidades de 50 g.',
#   'Sin gluten',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=120'],
#  ['\n2,10 €',
#   '1,75 €/l',
#   'Batido de chocolate Puleva sin gluten pack de 6 briks de 200 ml.',
#   'Sin gluten',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=120'],
#  ['\n4,89 €',
#   '4,89 €/l',
#   'Aceite de oliva suave 0,4º La Española 1 l.',
#   'Ver productos de la promoción',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=120'],
#  ['\n2,35 €',
#   '9,40 €/kg',
#   'Mantequilla tradicional sin sal Central Lechera Asturiana 250 g.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=120'],
#  ['\n5,85 €',
#   '5,85 €/l',
#   'Aceite de oliva virgen extra Dcoop 1 l.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=144'],
#  ['\n0,35 €',
#   '31,82 €/kg',
#   'Orégano Carrefour 11 g.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=144'],
#  ['\n0,70 €',
#   '1,40 €/kg',
#   'Fideuá Carrefour 500 g.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=144'],
#  ['\n0,69 €',
#   '1,38 €/kg',
#   'Espirales vegetales Carrefour 500 g.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=144'],
#  ['\n1,13 €',
#   '4,52 €/kg',
#   'Café molido natural Carrefour 250 g.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=144'],
#  ['\n1,25 €',
#   '0,83 €/l',
#   'Leche entera Central Lechera Asturiana botella 1,5 l.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=144'],
#  ['\n1,54 €',
#   '2,80 €/kg',
#   'Salsa de tomate De la Abuela Carrefour tarro 580 g.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=144'],
#  ['\n1,85 €',
#   '4,40 €/kg',
#   'Guisantes muy finos Classic Carrefour pack de 3 latas de 140 g.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=144'],
#  ['\n5,29 €',
#   '6,96 €/kg',
#   'Cacao soluble original Cola Cao 760 g.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=168'],
#  ['\n3,24 €',
#   '9,26 €/kg',
#   'Pizza caprese fina y crujiente Forno di Pietra Buitoni 350 g.',
#   'Congelado',
#   'Ver productos de la promoción',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=168'],
#  ['\n0,99 €',
#   '4,40 €/kg',
#   'Pimientos del Piquillo asados en tiras primera Carrefour sin lactosa 225 g.',
#   'Sin lactosa',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=168'],
#  ['\n3,59 €',
#   '4,79 €/kg',
#   'Cereales integrales de chocolate Chocapic Nestlé 750 g.',
#   'Ver productos de la promoción',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=168'],
#  ['\n1,20 €',
#   '9,23 €/kg',
#   'Sardinillas en aceite de oliva Carrefour pack de 2 unidades de 65 g.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=168'],
#  ['\n1,45 €',
#   '9,06 €/kg',
#   'Galletas con pepitas de chocolate Minis Chips Ahoy 160 g.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=168'],
#  ['\n1,05 €',
#   '4,20 €/kg',
#   'Turrón de chocolate con leche crujiente Carrefour sin gluten 250 g.',
#   'Sin gluten',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=168'],
#  ['\n1,99 €',
#   '4,74 €/kg',
#   'Maiz dulce Carrefour pack de 6 unidades de 70 g.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=168'],
#  ['\n0,98 €',
#   '0,49 €/kg',
#   'Harina de trigo Carrefour 2 kg.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=192'],
#  ['\n1,35 €',
#   '1,13 €/l',
#   'Leche entera Carrefour pack de 6 briks de 200 ml.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=192'],
#  ['\n3,56 €',
#   '11,41 €/kg',
#   'Atún en aceite de oliva pack de 6 latas de 52 g.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=192'],
#  ['\n2,09 €',
#   '4,35 €/kg',
#   'Yogur bífidus desnatado cremoso de vainilla de madagascar Danone Activia pack de 4 unidades de 120 g.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=192'],
#  ['\n2,07 €',
#   '2,07 €/kg',
#   'Arroz basmati Carrefour 1 kg.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=192'],
#  ['\n3,35 €',
#   '1,67 €/l',
#   'Caldo casero de verduras Gallina Blanca pack de 2 briks de 1 l.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=192'],
#  ['\n4,59 €',
#   '5,10 €/kg',
#   'Galletas rellenas de crema de chocolate Príncipe pack de 3 unidades de 300 g.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=192'],
#  ['\n1,51 €',
#   '1,29 €/kg',
#   'Tomate frito con aceite de oliva virgen extra Carrefour pack de 3 briks de 390 g.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=192'],
#  ['\n0,80 €',
#   '5,33 €/kg',
#   'Patatas fritas estilo churrería Carrefour 150 g.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=216'],
#  ['\n2,63 €',
#   '6,49 €/kg',
#   'Pizza de jamón y queso Casa Tarradellas 405 g.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=216'],
#  ['\n3,95 €',
#   '7,90 €/kg',
#   'Café molido natural cultivo sostenible Nestlé Bonka 500 g.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=216'],
#  ['\n0,71 €',
#   '0,35 €/kg',
#   'Hielo en cubitos Carrefour 2 kg.',
#   'Congelado',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=216'],
#  ['\n1,45 €',
#   '9,06 €/kg',
#   'Galletas de chocolate rellenas de crema Mini Oreo pack de 4 unidades de 40 g.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=216'],
#  ['\n2,19 €',
#   '2,19 €/kg',
#   'Arroz tres delicias Carrefour 1 kg.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=216'],
#  ['\n0,99 €',
#   '2,75 €/kg',
#   'Judías verdes troceadas al natural La Hacienda de Ybarra 360 g.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=216'],
#  ['\n0,80 €',
#   '1,60 €/kg',
#   'Espaguetis integrales Carrefour 500 g.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=216'],
#  ['\n1,85 €',
#   '5,29 €/kg',
#   'Mermelada de fresa de temporada Hero 350 g.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=240'],
#  ['\n1,49 €',
#   '11,46 €/kg',
#   'Filetes de caballa del sur en aceite de oliva Carrefour pack de 2 latas de 65 g.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=240'],
#  ['\n1,99 €',
#   '7,96 €/kg',
#   'Mantequilla ecológica Carrefour Bio 250 g.',
#   'Bio',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=240'],
#  ['\n0,80 €',
#   '1,60 €/kg',
#   'Macarrones integrales Carrefour 500 g.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=240'],
#  ['\n1,59 €',
#   '6,91 €/kg',
#   'Yogur con bolitas cubiertas de chocolate Mix-in Nestlé Kit Kat pack de 2 unidades de 115 g.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=240'],
#  ['\n2,29 €',
#   '15,90 €/kg',
#   'Calamares en su tinta Calvo sin gluten y sin lactosa pack de 3 unidades de 48 g.',
#   'Sin gluten',
#   'Sin lactosa',
#   'Ver productos de la promoción',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=240'],
#  ['\n1,54 €',
#   '9,62 €/kg',
#   'Patatas fritas onduladas sabor jamón Ruffles 160 g.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=240'],
#  ['\n1,41 €',
#   '7,83 €/kg',
#   'Doble caldo carne Knorr sin gluten y sin lactosa 18 pastillas',
#   'Sin gluten',
#   'Sin lactosa',
#   'Ver productos de la promoción',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=240'],
#  ['\n1,19 €',
#   '2,38 €/kg',
#   'Yogur de limón Danone sin gluten pack de 4 unidades de 120 g.',
#   'Sin gluten',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=264'],
#  ['\n2,29 €',
#   '2,09 €',
#   '15,90 €/kg\n | \n14,51 €/kg',
#   'Calamares en salsa americana Calvo sin gluten y sin lactosapack de 3 unidades de 48 g.',
#   'Sin gluten',
#   'Sin lactosa',
#   'Ver productos de la promoción',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=264'],
#  ['\n1,19 €',
#   '9,22 €/kg',
#   'Mejillones de las rías gallegas en escabeche Carrefour sin gluten pack de 3 unidades de 43 g.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=264'],
#  ['\n3,48 €',
#   '10,55 €/kg',
#   'Pizza prosciutto Ristorante Dr. Oetker 330 g.',
#   'Congelado',
#   'Ver productos de la promoción',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=264'],
#  ['\n2,79 €',
#   '5,37 €/kg',
#   'Puré de patatas Maggi sin gluten 520 g.',
#   'Sin gluten',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=264'],
#  ['\n1,84 €',
#   '3,68 €/l',
#   'Vinagre balsámico de módena Carrefour 500 ml.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=264'],
#  ['\n2,14 €',
#   '2,14 €/kg',
#   'Yogur azucarado natural Danone pack de 8 unidades de 120 g.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=264'],
#  ['\n3,11 €',
#   '3,11 €/kg',
#   'Arroz basmati Sundari 1 Kg.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=264'],
#  ['\n0,95 €',
#   '2,37 €/kg',
#   'Alubia cocida categoría extra Luengo 400 g.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=288'],
#  ['\n5,99 €',
#   '4,28 €/kg',
#   'Yogur L.Casei líquido con fresa Danone - Actimel kids pack de 14 unidades de 100 g.',
#   'Ver productos de la promoción',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=288'],
#  ['\n0,99 €',
#   '0,99 €/l',
#   'Caldo de pescado Carrefour sin gluten 1 l.',
#   'Sin gluten',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=288'],
#  ['\n0,71 €',
#   '1,42 €/kg',
#   'Cuscús grano mediano Carrefour 500 g.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=288'],
#  ['\n2,29 €',
#   '5,72 €/kg',
#   'Yogur líquido de fresa Danone Danonino pack de 4 unidades de 100 g.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=288'],
#  ['\n0,80 €',
#   '1,60 €/kg',
#   'Churros lazo Carrefour sin lactosa 500 g.',
#   'Congelado',
#   'Sin lactosa',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=288'],
#  ['\n0,96 €',
#   '32 €/kg',
#   'Anchoas en aceite de oliva Carrefour 50 g.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=288'],
#  ['\n1,39 €',
#   '2,78 €/kg',
#   'Maíz para palomitas Carrefour500 g.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=288'],
#  ['\n1,28 €',
#   '2,56 €/kg',
#   'Copos de avena integral ecológicos Carrefour Bio 500 g.',
#   'Bio',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=312'],
#  ['\n1,60 €',
#   '3,27 €/kg',
#   'Piña con zumo de piña en rodajas Carrefour 490 g.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=312'],
#  ['\n1,56 €',
#   '9,75 €/kg',
#   "Patatas fritas sabor campesinas Lay's 160 g.",
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=312'],
#  ['\n2,40 €',
#   '8 €/kg',
#   'Palomitas al punto de sal para microondas Popitas sin gluten pack de 3 unidades de 100 g.',
#   'Sin gluten',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=312'],
#  ['\n1,75 €',
#   '14 €/kg',
#   'Galletas con pepitas de chocolate sin azúcares Zero Gullón 125 g.',
#   'Ver productos de la promoción',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=312'],
#  ['\n3,49 €',
#   '8,72 €/kg',
#   'Galletas con pepitas de chocolate Chips Ahoy 400 g.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=312'],
#  ['\n0,75 €',
#   '1,50 €/kg',
#   'Spaguetti integral ecológico Carrefour Bio 500 g.',
#   'Bio',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=312'],
#  ['\n1,69 €',
#   '9,94 €/kg',
#   'Galletas finas con chocolate con leche Digestive Fontaneda 170 g.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=312'],
#  ['\n10,18 €',
#   '16,97 €/kg',
#   'Bombones de chocolate con leche y surtidos Lindt Lindor pack de 2 unidades de 200 g.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=336'],
#  ['\n1,43 €',
#   '9,79 €/kg',
#   'Tiras de maíz BBQ orginal Fritos 146 g.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=336'],
#  ['\n1,62 €',
#   '1,56 €',
#   '10,80 €/kg\n | \n10,40 €/kg',
#   'Aceitunas negras cacereñas sin hueso Serpis sin gluten y sin lactosa150 g.',
#   'Sin gluten',
#   'Ver productos de la promoción',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=336'],
#  ['\n4,75 €',
#   '11,87 €/kg',
#   'Pistachos tostados y saldaos Carrefour 400 g.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=336'],
#  ['\n5,29 €',
#   '10,58 €/kg',
#   'Café molido mezcla Gran Aroma Marcilla 500 g.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=336'],
#  ['\n2,19 €',
#   '4,38 €/kg',
#   'Galletas napolitana Cuétara 500 g.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=336'],
#  ['\n1,37 €',
#   '10,96 €/kg',
#   'Chocolate con leche y galleta Jungly Nestlé 125 g.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=336'],
#  ['\n1,85 €',
#   '9,25 €/kg',
#   'Café soluble natural Carrefour 200 g.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=336'],
#  ['\n2,09 €',
#   '4,35 €/kg',
#   'Yogur bífidus desnatado cremoso de frutos silvestres Danone Activia sin gluten pack de 4 unidades de 120 g.',
#   'Sin gluten',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=360'],
#  ['\n1,56 €',
#   '18,57 €/kg',
#   'Cortezas de trigoBoca Bits Matutano 84 g.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=360'],
#  ['\n1,06 €',
#   '10,60 €/kg',
#   'Chocolate negro 80% Carrefour Selección 100 g.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=360'],
#  ['\n0,74 €',
#   '5,92 €/l',
#   'Salsa de soja Carrefour botella 125 ml.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=360'],
#  ['\n0,52 €',
#   '2,48 €/kg',
#   'Garbanzos cocidos Carrefour 210 g.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=360'],
#  ['\n1,52 €',
#   '10,86 €/kg',
#   'Doritos Tex Mex 140 g.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=360'],
#  ['\n1,83 €',
#   '5,72 €/kg',
#   'Tortillas de trigo integrales Mexifoods 8 ud.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=360'],
#  ['\n2,25 €',
#   '4,50 €/kg',
#   "Nuggets de pollo Carrefour Classic' 500 g.",
#   'Congelado',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=360'],
#  ['\n1,99 €',
#   '1,82 €',
#   '4,97 €/kg\n | \n4,55 €/kg',
#   'Arroz redondo para microondasBrillante pack de 2 ud. de 200 g.',
#   'Ver productos de la promoción',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=384'],
#  ['\n4,05 €',
#   '3,75 €',
#   '4,05 €/kg\n | \n3,75 €/kg',
#   'Arroz bomba Sos 1 kg.',
#   'Ver productos de la promoción',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=384'],
#  ['\n0,80 €',
#   '0,80 €/l',
#   'Leche entera fresca Carrefour botella 1 l.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=384'],
#  ['\n2,47 €',
#   '9,88 €/kg',
#   'Turrón de Jijona Carrefour sin gluten 250 g.',
#   'Sin gluten',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=384'],
#  ['\n0,99 €',
#   '4,95 €/kg',
#   'Nachos clásicos Sensation Carrefour sin gluten 200 g.',
#   'Sin gluten',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=384'],
#  ['\n1,16 €',
#   '8,79 €/kg',
#   'Tortitas de maíz Carrefour pack de 4 unidades de 33 g. ',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=384'],
#  ['\n2,85 €',
#   '7,92 €/kg',
#   'Crema de avellanas original Nocilla sin gluten y sin aceite de palma 360 g.',
#   'Sin gluten',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=384'],
#  ['\n4,09 €',
#   '8,18 €/kg',
#   'Mantequilla tradicional Central Lechera Asturiana 500 g.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=384'],
#  ['\n0,47 €',
#   '0,94 €/kg',
#   'Yogur desnatado natural Carrefour pack de 4 unidades de 125 g.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=408'],
#  ['\n2,85 €',
#   '2,55 €',
#   '6,79 €/kg\n | \n6,07 €/kg',
#   'Guisantes tiernos y muy finos sin azúcares añadidos Bonduelle pack de 3 unidades de 140 g.',
#   'Ver productos de la promoción',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=408'],
#  ['\n0,92 €',
#   '3,07 €/kg',
#   'Salsa boloñesa Carrefour sin gluten tarro 300 g.',
#   'Sin gluten',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=408'],
#  ['\n0,88 €',
#   '1,83 €/kg',
#   'Tomate natural pelado Carrefour 480 g.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=408'],
#  ['\n1,73 €',
#   '3,46 €/kg',
#   'Cereales de maíz sin azúcar añadido Corn Flakes Carrefour 500 g.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=408'],
#  ['\n3,55 €',
#   '7,40 €/kg',
#   'Galletas con pepitas de chocolate Oceanix Tosta Rica Cuétara 480 g.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=408'],
#  ['\n0,60 €',
#   '6 €/kg',
#   'Aperitivo sabor queso Carrefour 100 g.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=408'],
#  ['\n3,12 €',
#   '3,78 €/l',
#   "Mayonesa Hellmann's tarro 825 ml.",
#   'Ver productos de la promoción',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=408'],
#  ['\n1,30 €',
#   '1,73 €/kg',
#   'Yogur griego de lima limón Carrefour Extra pack de 6 unidades de 125 g.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=432'],
#  ['\n2,89 €',
#   '14,45 €/kg',
#   'Avellanas tostadas Carrefour 200 g.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=432'],
#  ['\n5,69 €',
#   '0,02 €/kg',
#   'Atún claro en aceite de girasol Calvo pack de 6 latas de 52 g.',
#   'Ver productos de la promoción',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=432'],
#  ['\n1,71 €',
#   '4,07 €/kg',
#   'Leche evaporada -40% materia grasa Ideal pack de 2 briks de 210 g.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=432'],
#  ['\n0,72 €',
#   '0,72 €/l',
#   'Caldo de carne Carrefour sin gluten brik 1 l.',
#   'Sin gluten',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=432'],
#  ['\n2,69 €',
#   '2,65 €',
#   '38,99 €/kg\n | \n38,41 €/kg',
#   'Mejillones de las rías gallegas en escabeche Calvo sin gluten y sin lactosa 69 g.',
#   'Sin gluten',
#   'Sin lactosa',
#   'Ver productos de la promoción',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=432'],
#  ['\n2,87 €',
#   '2,39 €/l',
#   'Batido de cacao Cacaolat sin gluten pack de 6 briks de 200 ml.',
#   'Sin gluten',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=432'],
#  ['\n1,61 €',
#   '10,06 €/kg',
#   "Patatas fritas sabor vinagreta Lay's 160 g.",
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=432'],
#  ['\n3,24 €',
#   '10,80 €/kg',
#   'Pizza carbonara fina y crujiente forno di pietra Buitoni 300 g.',
#   'Congelado',
#   'Ver productos de la promoción',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=456'],
#  ['\n2,15 €',
#   '12,29 €/kg',
#   'Corazones de alcachofas mini 16/20 Carrefour sin lactosa 175 g.',
#   'Sin lactosa',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=456'],
#  ['\n1,37 €',
#   '1,85 €/kg',
#   'Leche condensada Carrefour 740 g.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=456'],
#  ['\n0,99 €',
#   '4,40 €/kg',
#   'Pimientos del Piquillo en tiras al ajillo Carrefour sin lactosa 225 g.',
#   'Sin lactosa',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=456'],
#  ['\n2,41 €',
#   '12,05 €/kg',
#   'Pistachos tostados y salados Carrefour 200 g.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=456'],
#  ['\n0,60 €',
#   '1,50 €/kg',
#   'Alubia cocida sin sal añadida Carrefour 400 g.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=456'],
#  ['\n2,09 €',
#   '1,90 €',
#   '17,42 €/kg\n | \n15,83 €/kg',
#   'Galletas rellena con crema de cacao Nocilla 120 g.',
#   'Ver productos de la promoción',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=456'],
#  ['\n0,78 €',
#   '2,60 €/kg',
#   'Palomitas saladas para microondas Carrefour pack de 3 bolsas de 100 g.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=456'],
#  ['\n1,20 €',
#   '2,67 €/kg',
#   'Fideo nº0 Gallo 450 g.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=480'],
#  ['\n0,99 €',
#   '4,95 €/l',
#   'Nata para cocinar Central Lechera Asturiana 200 ml.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=480'],
#  ['\n0,99 €',
#   '1,24 €/kg',
#   'Azúcar blanco Azucarera 800 g.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=480'],
#  ['\n2,59 €',
#   '5,18 €/l',
#   'Nata para cocinar espesa Président pack de 2 unidades de 250 ml.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=480'],
#  ['\n2,40 €',
#   '12 €/kg',
#   'Café soluble descafeinado Carrefour 200 g.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=480'],
#  ['\n0,99 €',
#   '8,25 €/kg',
#   'Risketos Risi sin gluten 120 g.',
#   'Sin gluten',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=480'],
#  ['\n5,99 €',
#   '5,99 €/l',
#   'Aceite de oliva virgen extra Maestros de Hojiblanca 1 l.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=480'],
#  ['\n1,39 €',
#   '5,79 €/kg',
#   'Corazones de alcachofa 8/10 Carrefour 240 g.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=480'],
#  ['\n0,99 €',
#   '1,98 €/l',
#   'Crema de verduras de la huerta Carrefour sin gluten 500 ml.',
#   'Sin gluten',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=504'],
#  ['\n0,99 €',
#   '1,98 €/l',
#   'Nata para montar líquida Carrefour 500 ml.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=504'],
#  ['\n0,77 €',
#   '3,85 €/kg',
#   'Caramelos de goma Carrefour Classic sin gluten 200 g.',
#   'Sin gluten',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=504'],
#  ['\n1,71 €',
#   '6,58 €/kg',
#   'Sopa de pollo con Maravilla Gallina Blanca pack de 3 sobres de 86 g.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=504'],
#  ['\n2,65 €',
#   '13,25 €/kg',
#   'Almendras tostadas sin sal añadida Carrefour 200 g.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=504'],
#  ['\n0,82 €',
#   '0,79 €',
#   '0,82 €/l\n | \n0,79 €/l',
#   'Leche desnatada 0% MG Central Lechera Asturiana brik 1 l.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=504'],
#  ['\n2,79 €',
#   '11,16 €/kg',
#   'Café molido natural crema e gusto Lavazza 250 g.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=504'],
#  ['\n2,99 €',
#   '2,99 €/ud',
#   'Tortilla de patata con cebolla 600 g',
#   'Ver productos de la promoción',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=504'],
#  ['\n0,99 €',
#   '1,98 €/l',
#   'Crema de calabacín con queso Carrefour sin gluten 500 ml.',
#   'Sin gluten',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=528'],
#  ['\n2,39 €',
#   '4,98 €/kg',
#   'Yogur bífidus desnatado con melocotón Danone Activia sin gluten pack de 4 unidades de 120 g.',
#   'Sin gluten',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=528'],
#  ['\n2,15 €',
#   '29,45 €/kg',
#   'Ventresca de atún claro en aceite de oliva Carrefour 73 g.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=528'],
#  ['\n5,99 €',
#   '5,99 €/l',
#   'Aceite de oliva virgen extra arbequina Coosur 1 l.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=528'],
#  ['\n2,05 €',
#   '1,87 €',
#   '4,10 €/l\n | \n3,74 €/l',
#   'Crema de Alicia de calabaza, zanahoria y guisantes Knorr 500 ml.',
#   'Ver productos de la promoción',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=528'],
#  ['\n4,15 €',
#   '5,53 €/kg',
#   "Cereales de arroz, trigo y cebada integral Special K Kellogg's 750 g.",
#   'Ver productos de la promoción',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=528'],
#  ['\n1,25 €',
#   '5 €/kg',
#   'Café molido mezcla Carrefour 250 g.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=528'],
#  ['\n1,39 €',
#   '3,86 €/kg',
#   'Petit Nestlé Nesquik sin gluten pack de 6 unidades de 60 g.',
#   'Sin gluten',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=528'],
#  ['\n2,49 €',
#   '6,23 €/kg',
#   'Calamares a la Romana Pescanova 400 g.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=552'],
#  ['\n2,05 €',
#   '8,20 €/kg',
#   "Patatas fritas sabor campesinas Lay's 250 g.",
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=552'],
#  ['\n2,28 €',
#   '4,56 €/kg',
#   'Café molido natural Carrefour 500 g.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=552'],
#  ['\n1,81 €',
#   '3,62 €/kg',
#   'Pasta mafalda corta Garofalo 500 g.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=552'],
#  ['\n1,65 €',
#   '0,75 €/l',
#   'Leche desnatada Central Lechera Asturiana botella 2,2 l.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=552'],
#  ['\n3,19 €',
#   '4,91 €/kg',
#   'Fresas Carrefour Classic 650 g.',
#   'Congelado',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=552'],
#  ['\n1,73 €',
#   '13,31 €/kg',
#   'Tomate concentrado Mutti 130 g.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=552'],
#  ['\n1,99 €',
#   '9,95 €/kg',
#   'Crema de berenjenas asadas Mutabal Realfooding Shukran 200 g.',
#   'Sin gluten',
#   'Sin lactosa',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=552'],
#  ['\n0,48 €',
#   '16 €/kg',
#   'Cebolla granulada Carrefour 30 g.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=576'],
#  ['\n5,99 €',
#   '4,28 €/kg',
#   'Yogur líquido con fresa y plátano Danone Actimel Kids sin gluten pack de 14 unidades de 100 g.',
#   'Sin gluten',
#   'Ver productos de la promoción',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=576'],
#  ['\n1,62 €',
#   '10,80 €/kg',
#   'Aceitunas verdes rellenas de anchoa La Española sin gluten 150 g.',
#   'Sin gluten',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=576'],
#  ['\n0,99 €',
#   '0,99 €/kg',
#   'Yogur desnatado líquido de fresa sin azúcar añadido con edulcorante Carrefour 1 kg.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=576'],
#  ['\n0,69 €',
#   '1,38 €/kg',
#   'Macarrones rayados vegetales Carrefour 500 g.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=576'],
#  ['\n2,60 €',
#   '6,93 €/kg',
#   'Cereales integrales con chocolate Chocapic Nestlé 375 g.',
#   'Ver productos de la promoción',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=576'],
#  ['\n0,90 €',
#   '9 €/kg',
#   'Chocolate negro 72% con pepitas de cacao tostadas caramelizadas Carrefour 100 g.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=576'],
#  ['\n4,59 €',
#   '6,12 €/kg',
#   'Galletas rellenas de crema de chocolate Maxi Choc Príncipe pack de 3 unidades de 250 g.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=576'],
#  ['\n2,75 €',
#   '43,65 €/kg',
#   'Berberechos al natural Cabo de Peñas 63 g.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=600'],
#  ['\n2,83 €',
#   '2,83 €/docena',
#   'Huevos M camperos Quien es el Jefe 12 ud.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=600'],
#  ['\n1,15 €',
#   '1,15 €/l',
#   'Leche desnatada Pascual sin lactosa brik 1 l.',
#   'Sin lactosa',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=600'],
#  ['\n2,85 €',
#   '7,92 €/kg',
#   'Crema de cacao y leche con avellanas Nocilla sin gluten y sin aceite de palma 360 g.',
#   'Sin gluten',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=600'],
#  ['\n4,15 €',
#   '10,37 €/kg',
#   'Nuggets rebozado fino Recetas Crujientes La Cocinera 400 g.',
#   'Congelado',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=600'],
#  ['\n3,29 €',
#   '7,31 €/kg',
#   "Cereales de maíz tostados y azucarados Frosties Kellogg's 450 g.",
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=600'],
#  ['\n2,69 €',
#   '2,69 €/kg',
#   'Lenteja pardina categoría extra De Nuestra Tierra 1 kg.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=600'],
#  ['\n0,60 €',
#   '4 €/kg',
#   'Aros de chocolate blanco Carrefour 150 g.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=600'],
#  ['\n1,57 €',
#   '17,44 €/kg',
#   'Almendras crudas sin cáscara sin sal añadida ecológicas Carrefour Bio 90 g.',
#   'Bio',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=624'],
#  ['\n1,70 €',
#   '4 €/kg',
#   'Garbanzos con espinacas Litoral 425 g.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=624'],
#  ['\n1,44 €',
#   '1,44 €/l',
#   'Leche desnatada con calcio Pascual brik 1 l.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=624'],
#  ['\n2,95 €',
#   '11,80 €/kg',
#   'Tortellini de jamón y queso Rana 250 g.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=624'],
#  ['\n0,85 €',
#   '0,85 €/l',
#   'Bebida de soja con calcio Carrefour sin gluten brik 1 l.',
#   'Sin gluten',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=624'],
#  ['\n1,30 €',
#   '2,60 €/kg',
#   'Kéfir natural Carrefour Sensation 500 g.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=624'],
#  ['\n1,38 €',
#   '12,55 €/kg',
#   'Espárrago blanco cortos extra Carretilla 110 g.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=624'],
#  ['\n2,14 €',
#   '2,23 €/kg',
#   'Yogur de fresa, de plátano, de macedonia y de tarta de queso Danone pack de 8 unidades de 120 g.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=624'],
#  ['\n2,95 €',
#   '5,36 €/kg',
#   'Kétchup 50% menos azúcar Heinz envase 550 g.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=648'],
#  ['\n1,99 €',
#   '3,98 €/kg',
#   'Cereales ecológicos Corn Flakes Carrefour Bio 500 g.',
#   'Bio',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=648'],
#  ['\n2,39 €',
#   '4,98 €/kg',
#   'Yogur bífidus de fibras con avena y nueces Danone Activia pack de 4 unidades de 120 g.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=648'],
#  ['\n5,99 €',
#   '4,28 €/kg',
#   'Yogur L.Casei líquido desnatado natural Danone Actimel pack de 14 unidades de 100 g.',
#   'Ver productos de la promoción',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=648'],
#  ['\n1,61 €',
#   '1,61 €/kg',
#   'Arroz blanco precocido Carrefour pack de 6 unidades de 167 g.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=648'],
#  ['\n1,40 €',
#   '3,50 €/l',
#   'Jugo de coco Carrefour 400 ml.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=648'],
#  ['\n2,09 €',
#   '6,53 €/kg',
#   'Yogur de proteínas sabor vainilla Danone Yopro sin gluten pack de 2 unidades de 160 g.',
#   'Sin gluten',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=648'],
#  ['\n0,69 €',
#   '9,72 €/kg',
#   'Pasta oriental noodles sabor pollo Maggi Fusian sin aceite de palma 71 g.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=648'],
#  ['\n1,15 €',
#   '5,75 €/l',
#   'Nata para cocinar Central Lechera Asturiana sin gluten sin lactosa 200 ml.',
#   'Sin gluten',
#   'Sin lactosa',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=672'],
#  ['\n3,20 €',
#   '2,75 €',
#   '18,82 €/kg\n | \n16,18 €/kg',
#   'Gyoza de carne al vapor Ta-Tung 170 g.',
#   'Ver productos de la promoción',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=672'],
#  ['\n2,09 €',
#   '10,45 €/kg',
#   'Anacardos fritos y salados Carrefour 200 g.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=672'],
#  ['\n2,99 €',
#   '5,98 €/kg',
#   'Tagliatelle nido Garofalo 500 g.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=672'],
#  ['\n2,05 €',
#   '4,77 €/kg',
#   'Alubias a la vasca Litoral 430 g.',
#   'Sin gluten',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=672'],
#  ['\n2,05 €',
#   '4,10 €/l',
#   'Crema de calabaza con un suave toque de nata Knorr 500 ml.',
#   'Ver productos de la promoción',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=672'],
#  ['\n1,62 €',
#   '2,70 €/kg',
#   'Tomate frito Solis pack 3 de 200 g.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=672'],
#  ['\n2,09 €',
#   '4,18 €/l',
#   'Salsa Ligeresa envase 500 ml.',
#   'Ver productos de la promoción',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=672'],
#  ['\n1,82 €',
#   '5,52 €/kg',
#   'Pizza prosciutto Carrefour 330 g.',
#   'Congelado',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=696'],
#  ['\n1,10 €',
#   '3,67 €/kg',
#   'Azúcar blanco en azucaritos Azucarera 300 g.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=696'],
#  ['\n2,99 €',
#   '4,98 €/kg',
#   'Yogur L.Casei líquido natural Danone Actimel pack de 6 unidades de 100 g.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=696'],
#  ['\n6,69 €',
#   '6,19 €',
#   '3,34 €/l\n | \n3,09 €/l',
#   'Caldo natural de verduras Aneto sin gluten y sin lactosa pack de 2 briks de 1 l.',
#   'Sin gluten',
#   'Sin lactosa',
#   'Ver productos de la promoción',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=696'],
#  ['\n2,29 €',
#   '5,72 €/kg',
#   'Flan de queso Danone sin gluten pack de 4 unidades de 100 g.',
#   'Sin gluten',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=696'],
#  ['\n0,99 €',
#   '2,33 €/kg',
#   'Espinacas sin sal añadida Carrefour 425 g.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=696'],
#  ['\n5,75 €',
#   '23,96 €/kg',
#   'Mejillones de las rías gallegas en escabeche Calvo sin gluten y sin lactosa pack de 6 unidades de 40 g.',
#   'Sin gluten',
#   'Sin lactosa',
#   'Ver productos de la promoción',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=696'],
#  ['\n1,06 €',
#   '3,21 €/kg',
#   'Mostaza original Prima envase 330 g.',
#   'Sin gluten',
#   'Ver productos de la promoción',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=696'],
#  ['\n5,40 €',
#   '6,92 €/kg',
#   'Crema de cacao con avellanas original Nocilla sin gluten y sin aceite de palma 780 g.',
#   'Sin gluten',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=720'],
#  ['\n1,45 €',
#   '6,30 €/kg',
#   'Guisantes extra finos ecológico Carrefour Bio 230 g.',
#   'Bio',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=720'],
#  ['\n2,69 €',
#   '8,41 €/kg',
#   'Galletas con pepitas de chocolate Mini Chips Ahoy 320 g.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=720'],
#  ['\n4,55 €',
#   '4,29 €',
#   '21,98 €/kg\n | \n20,72 €/kg',
#   'Mejillones de las rías gallegas en escabeche Calvo sin gluten y sin lactosa pack de 3 unidades de 69 g.',
#   'Sin gluten',
#   'Sin lactosa',
#   'Ver productos de la promoción',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=720'],
#  ['\n2,05 €',
#   '8,99 €/kg',
#   'Mousse de chocolate crujiente Nestlé Gold pack de 4 unidades de 57 g.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=720'],
#  ['\n2,65 €',
#   '2,65 €/kg',
#   'Arroz bomba para paella categoría extra Carrefour 1 kg.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=720'],
#  ['\n2,89 €',
#   '10,70 €/kg',
#   'Piccolinis 3 quesos Buitoni pack de 3 unidades de 90 g.',
#   'Ver productos de la promoción',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=720'],
#  ['\n2,63 €',
#   '6,05 €/kg',
#   'Pizza barbacoa Casa Tarradellas 440 g.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=720'],
#  ['\n3,15 €',
#   '3,15 €/l',
#   'Crema de Alicia de calabaza, zanahoria y guisantes Knorr 1 l.',
#   'Ver productos de la promoción',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=744'],
#  ['\n5,59 €',
#   '2,79 €/l',
#   'Caldo para paella fácil Gallina Blanca sin gluen pack de 2 briks de 1 l.',
#   'Sin gluten',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=744'],
#  ['\n0,99 €',
#   '3,30 €/kg',
#   'Kétchup Orlando Barrilito 300 g.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=744'],
#  ['\n0,90 €',
#   '6 €/kg',
#   'Patatas fritas sabor Campesina Carrefour 150 g.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=744'],
#  ['\n1,10 €',
#   '1,10 €/l',
#   'Bebida de almendras sin azúcar añadido Vegye sin gluten brik 1 l.',
#   'Sin gluten',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=744'],
#  ['\n1,55 €',
#   '2,38 €/kg',
#   'Mermelada de fresa catgoría extra Carrefour 650 g.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=744'],
#  ['\n2,05 €',
#   '12,06 €/kg',
#   'Chocolate con leche para repostería Nestlé Postres sin gluten 170 g.',
#   'Sin gluten',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=744'],
#  ['\n1,42 €',
#   '3,55 €/kg',
#   'Garbanzo castellano cocido De Nuestra Tierra 400 g.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/la-despensa/cat20001/c?offset=744'],
#  ['\n3,95 €',
#   '11,76 €/kg',
#   'Atún claro al natural Carrefour pack de 3 latas de 104 g.',
#   'Añadir\n',
# ...
#  ['\n7,35 €',
#   '3,71 €/l',
#   'Cerveza1906 pack de 4 Red Vintage 33 cl.+ 2 Galician Irish Red Ale 33 cl.+ Copa',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/bebidas/cat20003/c?offset=768'],
#  ['\n4,99 €',
#   '4,99 €/ud',
#   'El Hayedo Verdejo Blanco 2020',
#   'Bio',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/bebidas/cat20003/c?offset=768'],
#  ['\n0,61 €',
#   '2,44 €/l',
#   'Bebida energética Carrefour sabor frutos rojos 25 cl.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/bebidas/cat20003/c?offset=792'],
#  ['\n2,09 €',
#   '8,36 €/l',
#   'Smoothie de fresa y plátano Innocent sin azúcares añadidos botella 25 cl.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/bebidas/cat20003/c?offset=792'],
#  ['\n10,49 €',
#   '10,49 €/ud',
#   'Paco & Lola Blanco 2020',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/bebidas/cat20003/c?offset=792'],
#  ['\n2,09 €',
#   '2,09 €/ud',
#   'Vino frizzante blanco Joven Capel 75 cl.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/bebidas/cat20003/c?offset=792'],
#  ['\n0,99 €',
#   '1,32 €/l',
#   'Vino tinto Marqués Dospala botella 75 cl.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/bebidas/cat20003/c?offset=792'],
#  ['\n1,73 €',
#   '8,65 €/l',
#   'Tónica Schweppes con pimienta rosa premium botella 20 cl.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/bebidas/cat20003/c?offset=792'],
#  ['\n2,29 €',
#   '2,29 €/l',
#   'Néctar de piña Granini botella 1 l.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/bebidas/cat20003/c?offset=792'],
#  ['\n15,95 €',
#   '15,95 €/ud',
#   'Mar De Frades Blanco 2020',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/bebidas/cat20003/c?offset=792'],
#  ['\n13,39 €',
#   '19,13 €/l',
#   'Ginebra Larios Rosé premium 70 cl.',
#   'Ver productos de la promoción',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/bebidas/cat20003/c?offset=816'],
#  ['\n1,41 €',
#   '1,41 €/l',
#   'Cerveza San Miguel Especial botella 1 l.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/bebidas/cat20003/c?offset=816'],
#  ['\n12,15 €',
#   '12,15 €/l',
#   "Ginebra Gordon's 1 l.",
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/bebidas/cat20003/c?offset=816'],
#  ['\n0,92 €',
#   '2,79 €/l',
#   'Cerveza Ambar Export tostada Tres Maltas lata 33 cl.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/bebidas/cat20003/c?offset=816'],
#  ['\n13,90 €',
#   '13,90 €/ud',
#   'Estuche 2 Bot. Matsu El Picaro Tinto 2019',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/bebidas/cat20003/c?offset=816'],
#  ['\n5,95 €',
#   '8,50 €/l',
#   'Ron miel Yacaré 70 cl.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/bebidas/cat20003/c?offset=816'],
#  ['\n8,45 €',
#   '8,45 €/l',
#   'Bebida espirituosa Soberano 1 l.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/bebidas/cat20003/c?offset=816'],
#  ['\n1,74 €',
#   '5,27 €/l',
#   'Cerveza Grimbergen blonde botella 33 cl.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/bebidas/cat20003/c?offset=816'],
#  ['\n2,25 €',
#   '1,12 €/l',
#   'Vino tinto de mesa Vegas del Rivilla botella 2 l.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/bebidas/cat20003/c?offset=840'],
#  ['\n4,55 €',
#   '0,91 €/l',
#   'Vino tinto Señorío Extremeño 5 l.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/bebidas/cat20003/c?offset=840'],
#  ['\n0,79 €',
#   '2,55 €/l',
#   'Zumo de fresa Sunny Delight botella 31 cl.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/bebidas/cat20003/c?offset=840'],
#  ['\n1,06 €',
#   '2,12 €/l',
#   'Agua mineral con gas Vichy Catalán sabor naranja 50 cl.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/bebidas/cat20003/c?offset=840'],
#  ['\n3,29 €',
#   '2,19 €/l',
#   'Néctar multifrutas sin azucares añadidos Granini 1,5 l.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/bebidas/cat20003/c?offset=840'],
#  ['\n4,75 €',
#   '4,75 €/ud',
#   'La Guita Manzanilla Manzanilla',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/bebidas/cat20003/c?offset=840'],
#  ['\n20,95 €',
#   '20,95 €/ud',
#   'Estuche 2 Bot. Habla Del Silencio Tinto 2020',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/bebidas/cat20003/c?offset=840'],
#  ['\n8,70 €',
#   '12,43 €/l',
#   'Ginebra Larios 70 cl.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/bebidas/cat20003/c?offset=840'],
#  ['\n21 €',
#   '14 €/l',
#   'Whisky J&B escocés 1,5 l.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/bebidas/cat20003/c?offset=864'],
#  ['\n13,89 €',
#   '19,84 €/l',
#   'Jim Beam Bourbon Bourbon',
#   'Ver productos de la promoción',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/bebidas/cat20003/c?offset=864'],
#  ['\n2,05 €',
#   '2,05 €/ud',
#   'Vino D.O. Rioja blanco 3 Reinos 75 cl.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/bebidas/cat20003/c?offset=864'],
#  ['\n4,79 €',
#   '2,42 €/l',
#   'Tinto de verano con limón La Casera pack de 6 latas de 33 cl.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/bebidas/cat20003/c?offset=864'],
#  ['\n2,65 €',
#   '2,65 €/l',
#   'Zumo de zanahoria ecológico Delizum botella 1 l.',
#   'Bio',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/bebidas/cat20003/c?offset=864'],
#  ['\n1,51 €',
#   '6,04 €/l',
#   'Red Bull sabor sandia lata 25 cl.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/bebidas/cat20003/c?offset=864'],
#  ['\n4,53 €',
#   '4,53 €/ud',
#   'Sangre De Toro Tinto 2020',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/bebidas/cat20003/c?offset=864'],
#  ['\n5,79 €',
#   '5,79 €/ud',
#   'Freixenet Espumoso Blanco Sin Alcohol',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/bebidas/cat20003/c?offset=864'],
#  ['\n10,75 €',
#   '10,75 €/ud',
#   'Protos Tinto Fino Tinto 2020',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/bebidas/cat20003/c?offset=888'],
#  ['\n10,70 €',
#   '10,70 €/ud',
#   'Codorniu Cava',
#   'Bio',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/bebidas/cat20003/c?offset=888'],
#  ['\n2,69 €',
#   '1,79 €/l',
#   'Cerveza San Miguel especial Lager pack de 6 botellas de 25 cl.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/bebidas/cat20003/c?offset=888'],
#  ['\n0,70 €',
#   '2,12 €/l',
#   'Cerveza Mahou 5 Estrellas Radler con limón lata 33 cl.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/bebidas/cat20003/c?offset=888'],
#  ['\n4,75 €',
#   '0,95 €/l',
#   'Vino de la Tierra de Extremadura tinto Señorío Extremeño grifo 5 l.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/bebidas/cat20003/c?offset=888'],
#  ['\n1,47 €',
#   '5,88 €/l',
#   'Red Bull the acaí edition bebida energética sin azúcar lata 25 cl.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/bebidas/cat20003/c?offset=888'],
#  ['\n1,70 €',
#   '1,70 €/l',
#   'Néctar de piña Minute Maid sin azúcares añadidos botella 1 l.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/bebidas/cat20003/c?offset=888'],
#  ['\n17,69 €',
#   '17,69 €/ud',
#   'Juve & Camps De La Familia Cava 2017',
#   'Bio',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/bebidas/cat20003/c?offset=888'],
#  ['\n33,99 €',
#   '33,99 €/ud',
#   'Estuche 2 Bot. Arzuaga Tinto 2018',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/bebidas/cat20003/c?offset=912'],
#  ['\n6,55 €',
#   '9,36 €/l',
#   'Orujo blanco Puntemiño 70 cl.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/bebidas/cat20003/c?offset=912'],
#  ['\n2,65 €',
#   '3,79 €/l',
#   'Licor de manzana verde Loch Castle 70 cl.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/bebidas/cat20003/c?offset=912'],
#  ['\n11,25 €',
#   '16,07 €/l',
#   'Licor de hierbas Jagermeister 70 cl.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/bebidas/cat20003/c?offset=912'],
#  ['\n1,77 €',
#   '8,85 €/l',
#   'Tónica Schweppes con limón y quinina premium botella 20 cl.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/bebidas/cat20003/c?offset=912'],
#  ['\n0,99 €',
#   '3,96 €/l',
#   'Agua con gas Perrier sabor piña y mango 25 cl.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/bebidas/cat20003/c?offset=912'],
#  ['\n2,39 €',
#   '1,19 €/l',
#   'Gaseosa Postobón La Colombiana sabor cola botella 2 l.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/bebidas/cat20003/c?offset=912'],
#  ['\n3,29 €',
#   '2,19 €/l',
#   'Bebida de fruta zanahoria y naranja sin azúcares añadidos Granini botella 1,5 l.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/bebidas/cat20003/c?offset=912'],
#  ['\n2,19 €',
#   '3,13 €/l',
#   'Sidra Trabanco natural70 cl.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/bebidas/cat20003/c?offset=936'],
#  ['\n10,50 €',
#   '10,50 €/ud',
#   'Lote 94. Estuche de 2 botellas de vino tinto crianza Castillo de Albai D.O Ca Rioja 75 cl. + Regalo 2 copas ',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/bebidas/cat20003/c?offset=936'],
#  ['\n7,45 €',
#   '7,45 €/ud',
#   'Vino rosado Ramón Bilbao D.O.Ca Rioja 75 cl.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/bebidas/cat20003/c?offset=936'],
#  ['\n1,59 €',
#   '1,15 €',
#   '3,18 €/l\n | \n2,30 €/l',
#   'Monster mule bebida energética lata 50 cl.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/bebidas/cat20003/c?offset=936'],
#  ['\n13,89 €',
#   '13,89 €/ud',
#   'Ramon Bilbao 2015',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/bebidas/cat20003/c?offset=936'],
#  ['\n6,29 €',
#   '2,10 €/l',
#   'Cerveza Especial Cruzcampo pack de 12 botellas de 25 cl.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/bebidas/cat20003/c?offset=936'],
#  ['\n2,09 €',
#   '1,39 €/l',
#   'Distinto con vino de verdejo y limón La Casera botella 1,5 l.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/bebidas/cat20003/c?offset=936'],
#  ['\n0,54 €',
#   '1,64 €/l',
#   'Aquarade sabor naranja lata 33 cl.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/bebidas/cat20003/c?offset=936'],
#  ['\n51,75 €',
#   '51,75 €/ud',
#   'Estuche 3 Bot. Emilio Moro Tinto 2018',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/bebidas/cat20003/c?offset=960'],
#  ['\n2,99 €',
#   '2,99 €/ud',
#   'Nefer Garnacha Tinto 2020',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/bebidas/cat20003/c?offset=960'],
#  ['\n6,49 €',
#   '6,49 €/ud',
#   'Ramon Bilbao Blanco 2020',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/bebidas/cat20003/c?offset=960'],
#  ['\n3,99 €',
#   '3,99 €/ud',
#   'Carrefour Eco 2020',
#   'Bio',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/bebidas/cat20003/c?offset=960'],
#  ['\n4,05 €',
#   '5,79 €/l',
#   'Concentrado de limón Pulco sin azúcar sin gas botella 70 cl.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/bebidas/cat20003/c?offset=960'],
#  ['\n10,99 €',
#   '10,99 €/ud',
#   'Caja de 6 botellas de vino tinto joven tempranillo Tres Reinos D.O.Ca. Rioja 75 cl.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/bebidas/cat20003/c?offset=960'],
#  ['\n2,75 €',
#   '2,75 €/ud',
#   'Cava Castell del Llac brut nature 75 cl.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/bebidas/cat20003/c?offset=960'],
#  ['\n1,53 €',
#   '1,53 €/l',
#   'Vino tinto de mesa Cumbre de Gredos brik 1 l.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/bebidas/cat20003/c?offset=960'],
#  ['\n19,98 €',
#   '19,98 €/ud',
#   'Elyssia',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/bebidas/cat20003/c?offset=984'],
#  ['\n7,49 €',
#   '7,49 €/ud',
#   'El Hayedo Tinto Roble 2018',
#   'Bio',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/bebidas/cat20003/c?offset=984'],
#  ['\n8,85 €',
#   '8,49 €',
#   '8,85 €/ud\n | \n8,49 €/ud',
#   'Anna De Codorniu Brut Ecológico Cava Reserva',
#   'Bio',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/bebidas/cat20003/c?offset=984'],
#  ['\n12,89 €',
#   '18,41 €/l',
#   'Crema irlandesa Baileys sabor café 70 cl.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/bebidas/cat20003/c?offset=984'],
#  ['\n1,22 €',
#   '1,22 €/ud',
#   'Vino D.O. Valdepeñas Rosado tempranillo Viña Lobón 75 cl.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/bebidas/cat20003/c?offset=984'],
#  ['\n2,59 €',
#   '7,85 €/l',
#   'Cerveza tostadaAlhambra Baltic Porter botella 33 cl.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/bebidas/cat20003/c?offset=984'],
#  ['\n0,79 €',
#   '2,55 €/l',
#   'Zumo Sunny Delight Florida botella 31 cl.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/bebidas/cat20003/c?offset=984'],
#  ['\n6,49 €',
#   '6,49 €/ud',
#   'La Ina Fino',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/bebidas/cat20003/c?offset=984'],
#  ['\n1,58 €',
#   '0,79 €/100g',
#   'Jabón de manos en pastilla Original Dove pack de 2 unidades de 100 g.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/perfumeria-e-higiene/cat20004/c?offset=24'],
#  ['\n2,39 €',
#   '2,29 €',
#   '3,19 €/100ml\n | \n3,05 €/100ml',
#   'Dentífrico blanqueador para dientes más blancos al instante Max White Optic Colgate 75 ml.',
#   'Ver productos de la promoción',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/perfumeria-e-higiene/cat20004/c?offset=24'],
#  ['\n1,70 €',
#   '3,40 €/100ml',
#   'Desodorante roll-on antitranspirante 48h 0% Alcohol Original Dove 50 ml.',
#   'Ver productos de la promoción',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/perfumeria-e-higiene/cat20004/c?offset=24'],
#  ['\n1,65 €',
#   '2,20 €/100ml',
#   'Dentífrico anticaries frescor a menta Triple Action Colgate 75 ml.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/perfumeria-e-higiene/cat20004/c?offset=24'],
#  ['\n4,59 €',
#   '0,12 €/ud',
#   'Compresas normal con alas ultrafina Ausonia 36 ud.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/perfumeria-e-higiene/cat20004/c?offset=24'],
#  ['\n1,20 €',
#   '0,16 €/100ml',
#   'Gel de ducha Hidratante Coco Carrefour 750 ml.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/perfumeria-e-higiene/cat20004/c?offset=24'],
#  ['\n1,18 €',
#   '0,16 €/100ml',
#   'Gel de ducha vainilla Carrefour 750 ml.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/perfumeria-e-higiene/cat20004/c?offset=24'],
#  ['\n4,79 €',
#   '0,20 €/ud',
#   'Compresas con alas para noche ultrafina Ausonia 24 ud.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/perfumeria-e-higiene/cat20004/c?offset=24'],
#  ['\n4,85 €',
#   '4,75 €',
#   '0,57 €/100ml\n | \n0,56 €/100ml',
#   'Champú hidratación intensa para cabello seco a dañado Tresemmé 855 ml.',
#   'Ver productos de la promoción',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/perfumeria-e-higiene/cat20004/c?offset=48'],
#  ['\n4,26 €',
#   '4,25 €',
#   '0,18 €/ud\n | \n0,18 €/ud',
#   'Tampones super con aplicador PearlTampax 24 ud.',
#   'Ver productos de la promoción',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/perfumeria-e-higiene/cat20004/c?offset=48'],
#  ['\n3,90 €',
#   '1,30 €/100ml',
#   'Mascarilla capilar reconstructora de keratina Repara & Protege Pantene Pro-V 300 ml.',
#   'Ver productos de la promoción',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/perfumeria-e-higiene/cat20004/c?offset=48'],
#  ['\n5,55 €',
#   '3,70 €/100ml',
#   'Dentífrico para dientes sensibles Duplo Pack Protección Diaria Sensodyne pack de 2 unidades de 75 ml.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/perfumeria-e-higiene/cat20004/c?offset=48'],
#  ['\n3,64 €',
#   '0,98 €/100ml',
#   "Champú protector para el pelo teñido Color Vive Elvive L'Oréal Paris 370 ml.",
#   'Ver productos de la promoción',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/perfumeria-e-higiene/cat20004/c?offset=48'],
#  ['\n3,29 €',
#   '0,97 €/100ml',
#   'Champú anticaspa Classic H&S 340 ml.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/perfumeria-e-higiene/cat20004/c?offset=48'],
#  ['\n2,79 €',
#   '1,39 €/100ml',
#   'Dentífrico Bicarbonato Blanqueador Signal pack de 2 unidades de 100 ml.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/perfumeria-e-higiene/cat20004/c?offset=48'],
#  ['\n4,38 €',
#   '1,09 €/100ml',
#   'Desodorante en spray Cobalt Blue anti-transpirante Rexona pack de 2 unidades de 200 ml.',
#   'Añadir\n',
#   'https://www.carrefour.es/supermercado/perfumeria-e-higiene/cat20004/c?offset=48'],
#  ...]

# %%
df = pd.DataFrame(lista_productos, columns = ['precio','precio/kg','producto','anadir','none','link','m',"k","s"])

# %%
nueve=[]
for i in lista_productos:
    if len(i)==5:
        nueve.append(i)

# %%
print(len(nueve)-len(lista_productos))
# Out:
# -541

# %%
df.to_csv("carrefour.csv")

# %%
df.shape
# Out:
# (2264, 9)

# %%
len(nueve)
# Out:
# 5

# %%
ocho=[]
for i in lista_productos:
    if len(i)==8:
        ocho.append(i)
len(ocho)
# Out:
# 20
