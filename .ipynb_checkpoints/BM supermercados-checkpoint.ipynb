# %%
import pandas as pd
import numpy as np
import re
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
import time
from selenium.webdriver.support.ui import Select
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.support.ui import Select
import math

# %%
s=Service("/mnt/c/Users/silvi/Desktop/ironhack/proyectos/proyecto2/pipeline_proyecto1-2/jupyter/chromedriver.exe")
driver = webdriver.Chrome(service=s)
opciones=Options()

opciones.add_experimental_option('excludeSwitches', ['enable-automation'])
opciones.add_experimental_option('useAutomationExtension', False)

opciones.headless=False    # si True, no aperece la ventana (headless=no visible)

opciones.add_argument('--start-maximized')         # comienza maximizado

opciones.add_argument('user-data-dir=selenium')    # mantiene las cookies

#opciones.add_extension('driver_folder/adblock.crx')       # adblocker

opciones.add_argument('--incognito')              # incognito

# %%
url = ('https://www.online.bmsupermercados.es/es')
driver.get(url)
time.sleep(5)

driver.find_element_by_css_selector('#CybotCookiebotDialogBodyLevelButtonLevelOptinAllowallSelection').click()
# Out:
# <ipython-input-23-08990f77abfd>:5: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_css_selector('#CybotCookiebotDialogBodyLevelButtonLevelOptinAllowallSelection').click()

# %%
body = driver.execute_script("return document.body")
source = body.get_attribute('innerHTML') 
soup_sc = BeautifulSoup(source, "html.parser")

# %%
ref=["https://www.online.bmsupermercados.es/es/c/frescos/2812","https://www.online.bmsupermercados.es/es/c/alimentacion/2811","https://www.online.bmsupermercados.es/es/c/bebidas/1690","https://www.online.bmsupermercados.es/es/c/congelados/1783","https://www.online.bmsupermercados.es/es/c/cuidado_del_hogar/2813","https://www.online.bmsupermercados.es/es/c/bebe/2297","https://www.online.bmsupermercados.es/es/c/cuidado_personal/2814","https://www.online.bmsupermercados.es/es/c/animales/2469"]

# %%
url = ('https://www.online.bmsupermercados.es/es/c/frescos/2812')
driver.get(url)
body = driver.execute_script("return document.body")
source = body.get_attribute('innerHTML') 
soup_sc = BeautifulSoup(source, "html.parser")

# %%
soup_sc
# Out:
# <app-root ng-version="7.0.4"><router-outlet></router-outlet></app-root>
# <script src="runtime.ec2944dd8b20ec099bf3.js" type="text/javascript"></script><script src="polyfills.e726ecb246e02ce0452c.js" type="text/javascript"></script><script src="scripts.e11612767e181934facc.js" type="text/javascript"></script><script src="main.ad3db466c27583917dc6.js" type="text/javascript"></script>

# %%
N=soup_sc.findAll("div",{"class": "widget-prod d-flex flex-column align-items-center ng-tns-c11-427 widget-prod__not_highlighted ng-star-inserted"})

# %%
N
# Out:
# []

# %%
lista_all=[]
for i in ref:
    url = i
    driver.get(url)
    driver.implicitly_wait(2)
    body = driver.execute_script("return document.body")
    source = body.get_attribute('innerHTML') 
    soup_sc = BeautifulSoup(source, "html.parser")
    N=soup_sc.findAll("span",{"class": "pagination__results-item"})
    text=[p.getText() for p in N][2]
    num = math.floor(int(text)/24)
    x=24
    for z in range(num-1):
        lista_all.append(f"{i}?offset={x}")
        x+=24
# Out:
# ['/es/c/ofertas/99999']

# %%
soup_sc
# Out:
# <iframe src="https://espfx.solution.weborama.fr/fcgi-bin/dispatch.fcgi?a.A=co&amp;a.si=4325&amp;a.cp=371&amp;a.ct=b&amp;gdpr_cmp_failure=1&amp;a.re=0.0&amp;a.isc=0&amp;da=1639156017&amp;g.ru=&amp;g.pu=https%3A//www.online.bmsupermercados.es/es&amp;a.opt=N1%3A0%2CN2%3A0%2CN3%3A0" style="height: 1px; width: 1px; border: 0px; position: absolute; display: none; left: 0px; top: 0px; z-index: 0;"></iframe><iframe src="https://esaod.solution.weborama.fr/fcgi-bin/dispatch.fcgi?a.A=co&amp;a.si=2837&amp;a.cp=193&amp;a.ct=b&amp;gdpr_cmp_failure=1&amp;a.re=0.0&amp;a.isc=0&amp;da=1639156017&amp;g.ru=&amp;g.pu=https%3A//www.online.bmsupermercados.es/es&amp;a.opt=N1%3A0%2CN2%3A0%2CN3%3A0" style="height: 1px; width: 1px; border: 0px; position: absolute; display: none; left: 0px; top: 0px; z-index: 0;"></iframe><div aria-describedby="CybotCookiebotDialogBodyContentTitle" dir="ltr" id="CybotCookiebotDialog" lang="es" name="CybotCookiebotDialog" ng-non-bindable="" role="dialog" style="display: none; pa
# ...
